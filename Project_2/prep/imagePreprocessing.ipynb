# %%
# Imports
import os
import shutil
from torchvision import transforms
from PIL import Image, ImageEnhance, ImageOps
import torch
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision.utils import save_image
from torchvision import datasets
from torch.utils.data import DataLoader
import warnings
import numpy as np
import cv2

# %%
# Variables
# Define directories
SOURCE_DIRS = ['./images', './augmented_images']  # List of source directories containing your original and augmented images
OUTPUT_DIR = './preprocessed_images'  # Destination directory for preprocessed images

images_by_label = {}

labels = {}

batch_size = 64

# Suppress the DecompressionBombWarning
warnings.simplefilter('ignore', Image.DecompressionBombWarning)

# %%
# Locate all classes in the source directories
for SOURCE_DIR in SOURCE_DIRS:
    for class_name in os.listdir(SOURCE_DIR):
        class_path = os.path.join(SOURCE_DIR, class_name)
        if os.path.isdir(class_path):
            if class_name not in labels:
                label_name = class_name + "_" + SOURCE_DIR
                labels[class_name] = []
            print(f'Found class {class_name} in {SOURCE_DIR}')
# Out:
# Found class Paper in ./images
# Found class Rock in ./images
# Found class Scissor in ./images
# Found class Paper in ./augmented_images
# Found class Rock in ./augmented_images
# Found class Scissor in ./augmented_images

# %%
# Load the data
for SOURCE_DIR in SOURCE_DIRS:
    for class_name in os.listdir(SOURCE_DIR):
        class_path = os.path.join(SOURCE_DIR, class_name)
        loader_name = class_name + "_" + SOURCE_DIR
        if not os.path.isdir(class_path):
            continue  # Skip if not a directory

        # Initialize list for the class if not already present
        if class_name not in images_by_label:
            images_by_label[loader_name] = []

        # Traverse images in the class folder
        for file_name in os.listdir(class_path):
            if file_name.endswith(('.png', '.jpg', '.jpeg')):  # Check for valid image extensions
                file_path = os.path.join(class_path, file_name)

                # Load the image
                image = Image.open(file_path)

                # Append the image to the corresponding label's list
                images_by_label[loader_name].append(image)

# Print summary
for label, images in images_by_label.items():
    print(f"Loaded {len(images)} images for label '{label}'.")
# Out:
# Loaded 40 images for label 'Paper_./images'.
# Loaded 54 images for label 'Rock_./images'.
# Loaded 39 images for label 'Scissor_./images'.
# Loaded 280 images for label 'Paper_./augmented_images'.
# Loaded 378 images for label 'Rock_./augmented_images'.
# Loaded 273 images for label 'Scissor_./augmented_images'.

# %%
def resize_with_aspect_ratio(image, size):
    # Resize the image while maintaining the aspect ratio
    wpercent = (size / float(image.size[0]))
    hsize = int((float(image.size[1]) * float(wpercent)))
    img = image.resize((size, hsize), Image.Resampling.LANCZOS)
    return img

# %%
def auto_exposure(img):
    # Convert the image to a numpy array
    img_array = np.array(img)

    # Split into R, G, B channels
    r, g, b = cv2.split(img_array)

    # Apply CLAHE to each channel
    clahe = cv2.createCLAHE(clipLimit=25.0, tileGridSize=(8, 8))
    r = clahe.apply(r)
    g = clahe.apply(g)
    b = clahe.apply(b)

    # Merge the channels back together
    img_array = cv2.merge([r, g, b])

    # Convert back to PIL Image
    final_img = Image.fromarray(img_array)

    return final_img

# %%
# Define preprocessing pipeline
preprocess_pipeline_training = transforms.Compose([
    transforms.Lambda(lambda img: resize_with_aspect_ratio(img, 256)),  # Resize the image while maintaining the aspect ratio
    transforms.CenterCrop(256),  # Center crop the image
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # Random color jitter for generalization
    transforms.Lambda(lambda img: auto_exposure(img)),  # Apply auto exposure
    transforms.ToTensor(),  # Convert the image to PyTorch tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize the image
])

preprocess_pipeline_testing = transforms.Compose([
    transforms.Lambda(lambda img: resize_with_aspect_ratio(img, 256)),  # Resize the image while maintaining the aspect ratio
    transforms.CenterCrop(256),  # Center crop the image
    transforms.Lambda(lambda img: auto_exposure(img)),  # Apply auto exposure
    transforms.ToTensor(),  # Convert the image to PyTorch tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize the image
])

# %%
# Dictionary to store combined datasets for each class
datasets_by_source_and_class = {SOURCE_DIR: {class_name: [] for class_name in labels.keys()} for SOURCE_DIR in SOURCE_DIRS}

# Accumulate datasets for each class
for SOURCE_DIR in SOURCE_DIRS:
    for class_name in labels.keys():
        class_path = os.path.join(SOURCE_DIR, class_name)
        print(class_path)
        if not os.path.isdir(class_path):
            continue  # Skip if not a directory

        # Use ImageFolder with a structure that ImageFolder expects
        dataset = ImageFolder(
        root=SOURCE_DIR, 
        transform=preprocess_pipeline_testing if SOURCE_DIR == './images' else preprocess_pipeline_training
        )


        # Filter dataset to include only images belonging to the current class
        class_indices = [i for i, (_, label) in enumerate(dataset.samples) if dataset.classes[label] == class_name]
        filtered_dataset = torch.utils.data.Subset(dataset, class_indices)

        datasets_by_source_and_class[SOURCE_DIR][class_name].append(filtered_dataset)

        print(f"Preprocessed {len(filtered_dataset)} images for class '{SOURCE_DIR} {class_name}'.")
# Out:
# ./images\Paper
# Preprocessed 40 images for class './images Paper'.
# ./images\Rock
# Preprocessed 54 images for class './images Rock'.
# ./images\Scissor
# Preprocessed 39 images for class './images Scissor'.
# ./augmented_images\Paper
# Preprocessed 280 images for class './augmented_images Paper'.
# ./augmented_images\Rock
# Preprocessed 378 images for class './augmented_images Rock'.
# ./augmented_images\Scissor
# Preprocessed 273 images for class './augmented_images Scissor'.

# %%
data_loaders_by_class_and_source = {}

for SOURCE_DIR, class_datasets in datasets_by_source_and_class.items():
    for class_name, dataset_list in class_datasets.items():
        # Combine all filtered datasets for this class and source directory
        if len(dataset_list) > 1:
            combined_dataset = torch.utils.data.ConcatDataset(dataset_list)
        else:
            combined_dataset = dataset_list[0]  # If only one dataset, no need to concatenate

        # Create a DataLoader for this class and source directory
        dataloader = DataLoader(combined_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
        
        # Store the dataloader by class and source directory
        data_loaders_by_class_and_source[(class_name, SOURCE_DIR)] = dataloader

        print(f'Loaded {len(combined_dataset)} images for class {class_name} from {SOURCE_DIR}.')
# Out:
# Loaded 40 images for class Paper from ./images.
# Loaded 54 images for class Rock from ./images.
# Loaded 39 images for class Scissor from ./images.
# Loaded 280 images for class Paper from ./augmented_images.
# Loaded 378 images for class Rock from ./augmented_images.
# Loaded 273 images for class Scissor from ./augmented_images.

# %%
# Create the output directory if it doesn't exist
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
else:
    # Delete directory if it already exists
    shutil.rmtree(OUTPUT_DIR)
    os.makedirs(OUTPUT_DIR)

print(f"Created/checked directory: {OUTPUT_DIR}")	

# Create training and test directories
train_dir = os.path.join(OUTPUT_DIR, 'train')
test_dir = os.path.join(OUTPUT_DIR, 'test')

os.makedirs(train_dir)
os.makedirs(test_dir)

print(f"Created directory: {train_dir}")
print(f"Created directory: {test_dir}")
# Out:
# Created/checked directory: ./preprocessed_images
# Created directory: ./preprocessed_images\train
# Created directory: ./preprocessed_images\test

# %%
print("Processing and saving images...")

train_dir = os.path.join(OUTPUT_DIR, 'train')
test_dir = os.path.join(OUTPUT_DIR, 'test')

# Ensure the directories exist
os.makedirs(train_dir, exist_ok=True)
os.makedirs(test_dir, exist_ok=True)

for (class_name, SOURCE_DIR), dataloader in data_loaders_by_class_and_source.items():
    print(f"Processing and saving images for class '{SOURCE_DIR} {class_name}'...")

    if SOURCE_DIR == './images':
        label = 'test'
        class_dir = os.path.join(test_dir, class_name)
    else:
        label = 'train'
        class_dir = os.path.join(train_dir, class_name)

    # Create a subdirectory for the class
    os.makedirs(class_dir, exist_ok=True)

    # Iterate through the DataLoader batches
    for batch_idx, (images, labels) in enumerate(dataloader):
        print(f"Processing batch {batch_idx} of {label}...")
        for img_idx, image in enumerate(images):
            print(f"Processing image {img_idx+(batch_idx*img_idx)}...")

            # Generate a unique filename
            save_path = os.path.join(
                class_dir,
                f"{class_name}_{img_idx+(batch_idx*img_idx):03d}.jpg"
            )

            # Save the preprocessed image
            save_image(image, save_path)
            print(f"Saved: {save_path}")
            
        print(f"Batch {batch_idx} of {label} complete!")

print("Preprocessing complete!")
# Out:
# Processing and saving images...
# Processing and saving images for class './images Paper'...
# Processing batch 0 of test...
# Processing image 0...
# Saved: ./preprocessed_images\test\Paper\Paper_000.jpg
# Processing image 1...
# Saved: ./preprocessed_images\test\Paper\Paper_001.jpg
# Processing image 2...
# Saved: ./preprocessed_images\test\Paper\Paper_002.jpg
# Processing image 3...
# Saved: ./preprocessed_images\test\Paper\Paper_003.jpg
# Processing image 4...
# Saved: ./preprocessed_images\test\Paper\Paper_004.jpg
# Processing image 5...
# Saved: ./preprocessed_images\test\Paper\Paper_005.jpg
# Processing image 6...
# Saved: ./preprocessed_images\test\Paper\Paper_006.jpg
# Processing image 7...
# Saved: ./preprocessed_images\test\Paper\Paper_007.jpg
# Processing image 8...
# Saved: ./preprocessed_images\test\Paper\Paper_008.jpg
# Processing image 9...
# Saved: ./preprocessed_images\test\Paper\Paper_009.jpg
# Processing image 10...
# Saved: ./preprocessed_images\test\Paper\Paper_010.jpg
# Processing image 11...
# Saved: ./preprocessed_images\test\Paper\Paper_011.jpg
# Processing image 12...
# Saved: ./preprocessed_images\test\Paper\Paper_012.jpg
# Processing image 13...
# Saved: ./preprocessed_images\test\Paper\Paper_013.jpg
# Processing image 14...
# Saved: ./preprocessed_images\test\Paper\Paper_014.jpg
# Processing image 15...
# Saved: ./preprocessed_images\test\Paper\Paper_015.jpg
# Processing image 16...
# Saved: ./preprocessed_images\test\Paper\Paper_016.jpg
# Processing image 17...
# Saved: ./preprocessed_images\test\Paper\Paper_017.jpg
# Processing image 18...
# Saved: ./preprocessed_images\test\Paper\Paper_018.jpg
# Processing image 19...
# Saved: ./preprocessed_images\test\Paper\Paper_019.jpg
# Processing image 20...
# Saved: ./preprocessed_images\test\Paper\Paper_020.jpg
# Processing image 21...
# Saved: ./preprocessed_images\test\Paper\Paper_021.jpg
# Processing image 22...
# Saved: ./preprocessed_images\test\Paper\Paper_022.jpg
# Processing image 23...
# Saved: ./preprocessed_images\test\Paper\Paper_023.jpg
# Processing image 24...
# Saved: ./preprocessed_images\test\Paper\Paper_024.jpg
# Processing image 25...
# Saved: ./preprocessed_images\test\Paper\Paper_025.jpg
# Processing image 26...
# Saved: ./preprocessed_images\test\Paper\Paper_026.jpg
# Processing image 27...
# Saved: ./preprocessed_images\test\Paper\Paper_027.jpg
# Processing image 28...
# Saved: ./preprocessed_images\test\Paper\Paper_028.jpg
# Processing image 29...
# Saved: ./preprocessed_images\test\Paper\Paper_029.jpg
# Processing image 30...
# Saved: ./preprocessed_images\test\Paper\Paper_030.jpg
# Processing image 31...
# Saved: ./preprocessed_images\test\Paper\Paper_031.jpg
# Processing image 32...
# Saved: ./preprocessed_images\test\Paper\Paper_032.jpg
# Processing image 33...
# Saved: ./preprocessed_images\test\Paper\Paper_033.jpg
# Processing image 34...
# Saved: ./preprocessed_images\test\Paper\Paper_034.jpg
# Processing image 35...
# Saved: ./preprocessed_images\test\Paper\Paper_035.jpg
# Processing image 36...
# Saved: ./preprocessed_images\test\Paper\Paper_036.jpg
# Processing image 37...
# Saved: ./preprocessed_images\test\Paper\Paper_037.jpg
# Processing image 38...
# Saved: ./preprocessed_images\test\Paper\Paper_038.jpg
# Processing image 39...
# Saved: ./preprocessed_images\test\Paper\Paper_039.jpg
# Batch 0 of test complete!
# Processing and saving images for class './images Rock'...
# Processing batch 0 of test...
# Processing image 0...
# Saved: ./preprocessed_images\test\Rock\Rock_000.jpg
# Processing image 1...
# Saved: ./preprocessed_images\test\Rock\Rock_001.jpg
# Processing image 2...
# Saved: ./preprocessed_images\test\Rock\Rock_002.jpg
# Processing image 3...
# Saved: ./preprocessed_images\test\Rock\Rock_003.jpg
# Processing image 4...
# Saved: ./preprocessed_images\test\Rock\Rock_004.jpg
# Processing image 5...
# Saved: ./preprocessed_images\test\Rock\Rock_005.jpg
# Processing image 6...
# Saved: ./preprocessed_images\test\Rock\Rock_006.jpg
# Processing image 7...
# Saved: ./preprocessed_images\test\Rock\Rock_007.jpg
# Processing image 8...
# Saved: ./preprocessed_images\test\Rock\Rock_008.jpg
# Processing image 9...
# Saved: ./preprocessed_images\test\Rock\Rock_009.jpg
# Processing image 10...
# Saved: ./preprocessed_images\test\Rock\Rock_010.jpg
# Processing image 11...
# Saved: ./preprocessed_images\test\Rock\Rock_011.jpg
# Processing image 12...
# Saved: ./preprocessed_images\test\Rock\Rock_012.jpg
# Processing image 13...
# Saved: ./preprocessed_images\test\Rock\Rock_013.jpg
# Processing image 14...
# Saved: ./preprocessed_images\test\Rock\Rock_014.jpg
# Processing image 15...
# Saved: ./preprocessed_images\test\Rock\Rock_015.jpg
# Processing image 16...
# Saved: ./preprocessed_images\test\Rock\Rock_016.jpg
# Processing image 17...
# Saved: ./preprocessed_images\test\Rock\Rock_017.jpg
# Processing image 18...
# Saved: ./preprocessed_images\test\Rock\Rock_018.jpg
# Processing image 19...
# Saved: ./preprocessed_images\test\Rock\Rock_019.jpg
# Processing image 20...
# Saved: ./preprocessed_images\test\Rock\Rock_020.jpg
# Processing image 21...
# Saved: ./preprocessed_images\test\Rock\Rock_021.jpg
# Processing image 22...
# Saved: ./preprocessed_images\test\Rock\Rock_022.jpg
# Processing image 23...
# Saved: ./preprocessed_images\test\Rock\Rock_023.jpg
# Processing image 24...
# Saved: ./preprocessed_images\test\Rock\Rock_024.jpg
# Processing image 25...
# Saved: ./preprocessed_images\test\Rock\Rock_025.jpg
# Processing image 26...
# Saved: ./preprocessed_images\test\Rock\Rock_026.jpg
# Processing image 27...
# Saved: ./preprocessed_images\test\Rock\Rock_027.jpg
# Processing image 28...
# Saved: ./preprocessed_images\test\Rock\Rock_028.jpg
# Processing image 29...
# Saved: ./preprocessed_images\test\Rock\Rock_029.jpg
# Processing image 30...
# Saved: ./preprocessed_images\test\Rock\Rock_030.jpg
# Processing image 31...
# Saved: ./preprocessed_images\test\Rock\Rock_031.jpg
# Processing image 32...
# Saved: ./preprocessed_images\test\Rock\Rock_032.jpg
# Processing image 33...
# Saved: ./preprocessed_images\test\Rock\Rock_033.jpg
# Processing image 34...
# Saved: ./preprocessed_images\test\Rock\Rock_034.jpg
# Processing image 35...
# Saved: ./preprocessed_images\test\Rock\Rock_035.jpg
# Processing image 36...
# Saved: ./preprocessed_images\test\Rock\Rock_036.jpg
# Processing image 37...
# Saved: ./preprocessed_images\test\Rock\Rock_037.jpg
# Processing image 38...
# Saved: ./preprocessed_images\test\Rock\Rock_038.jpg
# Processing image 39...
# Saved: ./preprocessed_images\test\Rock\Rock_039.jpg
# Processing image 40...
# Saved: ./preprocessed_images\test\Rock\Rock_040.jpg
# Processing image 41...
# Saved: ./preprocessed_images\test\Rock\Rock_041.jpg
# Processing image 42...
# Saved: ./preprocessed_images\test\Rock\Rock_042.jpg
# Processing image 43...
# Saved: ./preprocessed_images\test\Rock\Rock_043.jpg
# Processing image 44...
# Saved: ./preprocessed_images\test\Rock\Rock_044.jpg
# Processing image 45...
# Saved: ./preprocessed_images\test\Rock\Rock_045.jpg
# Processing image 46...
# Saved: ./preprocessed_images\test\Rock\Rock_046.jpg
# Processing image 47...
# Saved: ./preprocessed_images\test\Rock\Rock_047.jpg
# Processing image 48...
# Saved: ./preprocessed_images\test\Rock\Rock_048.jpg
# Processing image 49...
# Saved: ./preprocessed_images\test\Rock\Rock_049.jpg
# Processing image 50...
# Saved: ./preprocessed_images\test\Rock\Rock_050.jpg
# Processing image 51...
# Saved: ./preprocessed_images\test\Rock\Rock_051.jpg
# Processing image 52...
# Saved: ./preprocessed_images\test\Rock\Rock_052.jpg
# Processing image 53...
# Saved: ./preprocessed_images\test\Rock\Rock_053.jpg
# Batch 0 of test complete!
# Processing and saving images for class './images Scissor'...
# Processing batch 0 of test...
# Processing image 0...
# Saved: ./preprocessed_images\test\Scissor\Scissor_000.jpg
# Processing image 1...
# Saved: ./preprocessed_images\test\Scissor\Scissor_001.jpg
# Processing image 2...
# Saved: ./preprocessed_images\test\Scissor\Scissor_002.jpg
# Processing image 3...
# Saved: ./preprocessed_images\test\Scissor\Scissor_003.jpg
# Processing image 4...
# Saved: ./preprocessed_images\test\Scissor\Scissor_004.jpg
# Processing image 5...
# Saved: ./preprocessed_images\test\Scissor\Scissor_005.jpg
# Processing image 6...
# Saved: ./preprocessed_images\test\Scissor\Scissor_006.jpg
# Processing image 7...
# Saved: ./preprocessed_images\test\Scissor\Scissor_007.jpg
# Processing image 8...
# Saved: ./preprocessed_images\test\Scissor\Scissor_008.jpg
# Processing image 9...
# Saved: ./preprocessed_images\test\Scissor\Scissor_009.jpg
# Processing image 10...
# Saved: ./preprocessed_images\test\Scissor\Scissor_010.jpg
# Processing image 11...
# Saved: ./preprocessed_images\test\Scissor\Scissor_011.jpg
# Processing image 12...
# Saved: ./preprocessed_images\test\Scissor\Scissor_012.jpg
# Processing image 13...
# Saved: ./preprocessed_images\test\Scissor\Scissor_013.jpg
# Processing image 14...
# Saved: ./preprocessed_images\test\Scissor\Scissor_014.jpg
# Processing image 15...
# Saved: ./preprocessed_images\test\Scissor\Scissor_015.jpg
# Processing image 16...
# Saved: ./preprocessed_images\test\Scissor\Scissor_016.jpg
# Processing image 17...
# Saved: ./preprocessed_images\test\Scissor\Scissor_017.jpg
# Processing image 18...
# Saved: ./preprocessed_images\test\Scissor\Scissor_018.jpg
# Processing image 19...
# Saved: ./preprocessed_images\test\Scissor\Scissor_019.jpg
# Processing image 20...
# Saved: ./preprocessed_images\test\Scissor\Scissor_020.jpg
# Processing image 21...
# Saved: ./preprocessed_images\test\Scissor\Scissor_021.jpg
# Processing image 22...
# Saved: ./preprocessed_images\test\Scissor\Scissor_022.jpg
# Processing image 23...
# Saved: ./preprocessed_images\test\Scissor\Scissor_023.jpg
# Processing image 24...
# Saved: ./preprocessed_images\test\Scissor\Scissor_024.jpg
# Processing image 25...
# Saved: ./preprocessed_images\test\Scissor\Scissor_025.jpg
# Processing image 26...
# Saved: ./preprocessed_images\test\Scissor\Scissor_026.jpg
# Processing image 27...
# Saved: ./preprocessed_images\test\Scissor\Scissor_027.jpg
# Processing image 28...
# Saved: ./preprocessed_images\test\Scissor\Scissor_028.jpg
# Processing image 29...
# Saved: ./preprocessed_images\test\Scissor\Scissor_029.jpg
# Processing image 30...
# Saved: ./preprocessed_images\test\Scissor\Scissor_030.jpg
# Processing image 31...
# Saved: ./preprocessed_images\test\Scissor\Scissor_031.jpg
# Processing image 32...
# Saved: ./preprocessed_images\test\Scissor\Scissor_032.jpg
# Processing image 33...
# Saved: ./preprocessed_images\test\Scissor\Scissor_033.jpg
# Processing image 34...
# Saved: ./preprocessed_images\test\Scissor\Scissor_034.jpg
# Processing image 35...
# Saved: ./preprocessed_images\test\Scissor\Scissor_035.jpg
# Processing image 36...
# Saved: ./preprocessed_images\test\Scissor\Scissor_036.jpg
# Processing image 37...
# Saved: ./preprocessed_images\test\Scissor\Scissor_037.jpg
# Processing image 38...
# Saved: ./preprocessed_images\test\Scissor\Scissor_038.jpg
# Batch 0 of test complete!
# Processing and saving images for class './augmented_images Paper'...
# Processing batch 0 of train...
# Processing image 0...
# Saved: ./preprocessed_images\train\Paper\Paper_000.jpg
# Processing image 1...
# Saved: ./preprocessed_images\train\Paper\Paper_001.jpg
# Processing image 2...
# Saved: ./preprocessed_images\train\Paper\Paper_002.jpg
# Processing image 3...
# Saved: ./preprocessed_images\train\Paper\Paper_003.jpg
# Processing image 4...
# Saved: ./preprocessed_images\train\Paper\Paper_004.jpg
# Processing image 5...
# Saved: ./preprocessed_images\train\Paper\Paper_005.jpg
# Processing image 6...
# Saved: ./preprocessed_images\train\Paper\Paper_006.jpg
# Processing image 7...
# Saved: ./preprocessed_images\train\Paper\Paper_007.jpg
# Processing image 8...
# Saved: ./preprocessed_images\train\Paper\Paper_008.jpg
# Processing image 9...
# Saved: ./preprocessed_images\train\Paper\Paper_009.jpg
# Processing image 10...
# Saved: ./preprocessed_images\train\Paper\Paper_010.jpg
# Processing image 11...
# Saved: ./preprocessed_images\train\Paper\Paper_011.jpg
# Processing image 12...
# Saved: ./preprocessed_images\train\Paper\Paper_012.jpg
# Processing image 13...
# Saved: ./preprocessed_images\train\Paper\Paper_013.jpg
# Processing image 14...
# Saved: ./preprocessed_images\train\Paper\Paper_014.jpg
# Processing image 15...
# Saved: ./preprocessed_images\train\Paper\Paper_015.jpg
# Processing image 16...
# Saved: ./preprocessed_images\train\Paper\Paper_016.jpg
# Processing image 17...
# Saved: ./preprocessed_images\train\Paper\Paper_017.jpg
# Processing image 18...
# Saved: ./preprocessed_images\train\Paper\Paper_018.jpg
# Processing image 19...
# Saved: ./preprocessed_images\train\Paper\Paper_019.jpg
# Processing image 20...
# Saved: ./preprocessed_images\train\Paper\Paper_020.jpg
# Processing image 21...
# Saved: ./preprocessed_images\train\Paper\Paper_021.jpg
# Processing image 22...
# Saved: ./preprocessed_images\train\Paper\Paper_022.jpg
# Processing image 23...
# Saved: ./preprocessed_images\train\Paper\Paper_023.jpg
# Processing image 24...
# Saved: ./preprocessed_images\train\Paper\Paper_024.jpg
# Processing image 25...
# Saved: ./preprocessed_images\train\Paper\Paper_025.jpg
# Processing image 26...
# Saved: ./preprocessed_images\train\Paper\Paper_026.jpg
# Processing image 27...
# Saved: ./preprocessed_images\train\Paper\Paper_027.jpg
# Processing image 28...
# Saved: ./preprocessed_images\train\Paper\Paper_028.jpg
# Processing image 29...
# Saved: ./preprocessed_images\train\Paper\Paper_029.jpg
# Processing image 30...
# Saved: ./preprocessed_images\train\Paper\Paper_030.jpg
# Processing image 31...
# Saved: ./preprocessed_images\train\Paper\Paper_031.jpg
# Processing image 32...
# Saved: ./preprocessed_images\train\Paper\Paper_032.jpg
# Processing image 33...
# Saved: ./preprocessed_images\train\Paper\Paper_033.jpg
# Processing image 34...
# Saved: ./preprocessed_images\train\Paper\Paper_034.jpg
# Processing image 35...
# Saved: ./preprocessed_images\train\Paper\Paper_035.jpg
# Processing image 36...
# Saved: ./preprocessed_images\train\Paper\Paper_036.jpg
# Processing image 37...
# Saved: ./preprocessed_images\train\Paper\Paper_037.jpg
# Processing image 38...
# Saved: ./preprocessed_images\train\Paper\Paper_038.jpg
# Processing image 39...
# Saved: ./preprocessed_images\train\Paper\Paper_039.jpg
# Processing image 40...
# Saved: ./preprocessed_images\train\Paper\Paper_040.jpg
# Processing image 41...
# Saved: ./preprocessed_images\train\Paper\Paper_041.jpg
# Processing image 42...
# Saved: ./preprocessed_images\train\Paper\Paper_042.jpg
# Processing image 43...
# Saved: ./preprocessed_images\train\Paper\Paper_043.jpg
# Processing image 44...
# Saved: ./preprocessed_images\train\Paper\Paper_044.jpg
# Processing image 45...
# Saved: ./preprocessed_images\train\Paper\Paper_045.jpg
# Processing image 46...
# Saved: ./preprocessed_images\train\Paper\Paper_046.jpg
# Processing image 47...
# Saved: ./preprocessed_images\train\Paper\Paper_047.jpg
# Processing image 48...
# Saved: ./preprocessed_images\train\Paper\Paper_048.jpg
# Processing image 49...
# Saved: ./preprocessed_images\train\Paper\Paper_049.jpg
# Processing image 50...
# Saved: ./preprocessed_images\train\Paper\Paper_050.jpg
# Processing image 51...
# Saved: ./preprocessed_images\train\Paper\Paper_051.jpg
# Processing image 52...
# Saved: ./preprocessed_images\train\Paper\Paper_052.jpg
# Processing image 53...
# Saved: ./preprocessed_images\train\Paper\Paper_053.jpg
# Processing image 54...
# Saved: ./preprocessed_images\train\Paper\Paper_054.jpg
# Processing image 55...
# Saved: ./preprocessed_images\train\Paper\Paper_055.jpg
# Processing image 56...
# Saved: ./preprocessed_images\train\Paper\Paper_056.jpg
# Processing image 57...
# Saved: ./preprocessed_images\train\Paper\Paper_057.jpg
# Processing image 58...
# Saved: ./preprocessed_images\train\Paper\Paper_058.jpg
# Processing image 59...
# Saved: ./preprocessed_images\train\Paper\Paper_059.jpg
# Processing image 60...
# Saved: ./preprocessed_images\train\Paper\Paper_060.jpg
# Processing image 61...
# Saved: ./preprocessed_images\train\Paper\Paper_061.jpg
# Processing image 62...
# Saved: ./preprocessed_images\train\Paper\Paper_062.jpg
# Processing image 63...
# Saved: ./preprocessed_images\train\Paper\Paper_063.jpg
# Batch 0 of train complete!
# Processing batch 1 of train...
# Processing image 0...
# Saved: ./preprocessed_images\train\Paper\Paper_000.jpg
# Processing image 2...
# Saved: ./preprocessed_images\train\Paper\Paper_002.jpg
# Processing image 4...
# Saved: ./preprocessed_images\train\Paper\Paper_004.jpg
# Processing image 6...
# Saved: ./preprocessed_images\train\Paper\Paper_006.jpg
# Processing image 8...
# Saved: ./preprocessed_images\train\Paper\Paper_008.jpg
# Processing image 10...
# Saved: ./preprocessed_images\train\Paper\Paper_010.jpg
# Processing image 12...
# Saved: ./preprocessed_images\train\Paper\Paper_012.jpg
# Processing image 14...
# Saved: ./preprocessed_images\train\Paper\Paper_014.jpg
# Processing image 16...
# Saved: ./preprocessed_images\train\Paper\Paper_016.jpg
# Processing image 18...
# Saved: ./preprocessed_images\train\Paper\Paper_018.jpg
# Processing image 20...
# Saved: ./preprocessed_images\train\Paper\Paper_020.jpg
# Processing image 22...
# Saved: ./preprocessed_images\train\Paper\Paper_022.jpg
# Processing image 24...
# Saved: ./preprocessed_images\train\Paper\Paper_024.jpg
# Processing image 26...
# Saved: ./preprocessed_images\train\Paper\Paper_026.jpg
# Processing image 28...
# Saved: ./preprocessed_images\train\Paper\Paper_028.jpg
# Processing image 30...
# Saved: ./preprocessed_images\train\Paper\Paper_030.jpg
# Processing image 32...
# Saved: ./preprocessed_images\train\Paper\Paper_032.jpg
# Processing image 34...
# Saved: ./preprocessed_images\train\Paper\Paper_034.jpg
# Processing image 36...
# Saved: ./preprocessed_images\train\Paper\Paper_036.jpg
# Processing image 38...
# Saved: ./preprocessed_images\train\Paper\Paper_038.jpg
# Processing image 40...
# Saved: ./preprocessed_images\train\Paper\Paper_040.jpg
# Processing image 42...
# Saved: ./preprocessed_images\train\Paper\Paper_042.jpg
# Processing image 44...
# Saved: ./preprocessed_images\train\Paper\Paper_044.jpg
# Processing image 46...
# Saved: ./preprocessed_images\train\Paper\Paper_046.jpg
# Processing image 48...
# Saved: ./preprocessed_images\train\Paper\Paper_048.jpg
# Processing image 50...
# Saved: ./preprocessed_images\train\Paper\Paper_050.jpg
# Processing image 52...
# Saved: ./preprocessed_images\train\Paper\Paper_052.jpg
# Processing image 54...
# Saved: ./preprocessed_images\train\Paper\Paper_054.jpg
# Processing image 56...
# Saved: ./preprocessed_images\train\Paper\Paper_056.jpg
# Processing image 58...
# Saved: ./preprocessed_images\train\Paper\Paper_058.jpg
# Processing image 60...
# Saved: ./preprocessed_images\train\Paper\Paper_060.jpg
# Processing image 62...
# Saved: ./preprocessed_images\train\Paper\Paper_062.jpg
# Processing image 64...
# Saved: ./preprocessed_images\train\Paper\Paper_064.jpg
# Processing image 66...
# Saved: ./preprocessed_images\train\Paper\Paper_066.jpg
# Processing image 68...
# Saved: ./preprocessed_images\train\Paper\Paper_068.jpg
# Processing image 70...
# Saved: ./preprocessed_images\train\Paper\Paper_070.jpg
# Processing image 72...
# Saved: ./preprocessed_images\train\Paper\Paper_072.jpg
# Processing image 74...
# Saved: ./preprocessed_images\train\Paper\Paper_074.jpg
# Processing image 76...
# Saved: ./preprocessed_images\train\Paper\Paper_076.jpg
# Processing image 78...
# Saved: ./preprocessed_images\train\Paper\Paper_078.jpg
# Processing image 80...
# Saved: ./preprocessed_images\train\Paper\Paper_080.jpg
# Processing image 82...
# Saved: ./preprocessed_images\train\Paper\Paper_082.jpg
# Processing image 84...
# Saved: ./preprocessed_images\train\Paper\Paper_084.jpg
# Processing image 86...
# Saved: ./preprocessed_images\train\Paper\Paper_086.jpg
# Processing image 88...
# Saved: ./preprocessed_images\train\Paper\Paper_088.jpg
# Processing image 90...
# Saved: ./preprocessed_images\train\Paper\Paper_090.jpg
# Processing image 92...
# Saved: ./preprocessed_images\train\Paper\Paper_092.jpg
# Processing image 94...
# Saved: ./preprocessed_images\train\Paper\Paper_094.jpg
# Processing image 96...
# Saved: ./preprocessed_images\train\Paper\Paper_096.jpg
# Processing image 98...
# Saved: ./preprocessed_images\train\Paper\Paper_098.jpg
# Processing image 100...
# Saved: ./preprocessed_images\train\Paper\Paper_100.jpg
# Processing image 102...
# Saved: ./preprocessed_images\train\Paper\Paper_102.jpg
# Processing image 104...
# Saved: ./preprocessed_images\train\Paper\Paper_104.jpg
# Processing image 106...
# Saved: ./preprocessed_images\train\Paper\Paper_106.jpg
# Processing image 108...
# Saved: ./preprocessed_images\train\Paper\Paper_108.jpg
# Processing image 110...
# Saved: ./preprocessed_images\train\Paper\Paper_110.jpg
# Processing image 112...
# Saved: ./preprocessed_images\train\Paper\Paper_112.jpg
# Processing image 114...
# Saved: ./preprocessed_images\train\Paper\Paper_114.jpg
# Processing image 116...
# Saved: ./preprocessed_images\train\Paper\Paper_116.jpg
# Processing image 118...
# Saved: ./preprocessed_images\train\Paper\Paper_118.jpg
# Processing image 120...
# Saved: ./preprocessed_images\train\Paper\Paper_120.jpg
# Processing image 122...
# Saved: ./preprocessed_images\train\Paper\Paper_122.jpg
# Processing image 124...
# Saved: ./preprocessed_images\train\Paper\Paper_124.jpg
# Processing image 126...
# Saved: ./preprocessed_images\train\Paper\Paper_126.jpg
# Batch 1 of train complete!
# Processing batch 2 of train...
# Processing image 0...
# Saved: ./preprocessed_images\train\Paper\Paper_000.jpg
# Processing image 3...
# Saved: ./preprocessed_images\train\Paper\Paper_003.jpg
# Processing image 6...
# Saved: ./preprocessed_images\train\Paper\Paper_006.jpg
# Processing image 9...
# Saved: ./preprocessed_images\train\Paper\Paper_009.jpg
# Processing image 12...
# Saved: ./preprocessed_images\train\Paper\Paper_012.jpg
# Processing image 15...
# Saved: ./preprocessed_images\train\Paper\Paper_015.jpg
# Processing image 18...
# Saved: ./preprocessed_images\train\Paper\Paper_018.jpg
# Processing image 21...
# Saved: ./preprocessed_images\train\Paper\Paper_021.jpg
# Processing image 24...
# Saved: ./preprocessed_images\train\Paper\Paper_024.jpg
# Processing image 27...
# Saved: ./preprocessed_images\train\Paper\Paper_027.jpg
# Processing image 30...
# Saved: ./preprocessed_images\train\Paper\Paper_030.jpg
# Processing image 33...
# Saved: ./preprocessed_images\train\Paper\Paper_033.jpg
# Processing image 36...
# Saved: ./preprocessed_images\train\Paper\Paper_036.jpg
# Processing image 39...
# Saved: ./preprocessed_images\train\Paper\Paper_039.jpg
# Processing image 42...
# Saved: ./preprocessed_images\train\Paper\Paper_042.jpg
# Processing image 45...
# Saved: ./preprocessed_images\train\Paper\Paper_045.jpg
# Processing image 48...
# Saved: ./preprocessed_images\train\Paper\Paper_048.jpg
# Processing image 51...
# Saved: ./preprocessed_images\train\Paper\Paper_051.jpg
# Processing image 54...
# Saved: ./preprocessed_images\train\Paper\Paper_054.jpg
# Processing image 57...
# Saved: ./preprocessed_images\train\Paper\Paper_057.jpg
# Processing image 60...
# Saved: ./preprocessed_images\train\Paper\Paper_060.jpg
# Processing image 63...
# Saved: ./preprocessed_images\train\Paper\Paper_063.jpg
# Processing image 66...
# Saved: ./preprocessed_images\train\Paper\Paper_066.jpg
# Processing image 69...
# Saved: ./preprocessed_images\train\Paper\Paper_069.jpg
# Processing image 72...
# Saved: ./preprocessed_images\train\Paper\Paper_072.jpg
# Processing image 75...
# Saved: ./preprocessed_images\train\Paper\Paper_075.jpg
# Processing image 78...
# Saved: ./preprocessed_images\train\Paper\Paper_078.jpg
# Processing image 81...
# Saved: ./preprocessed_images\train\Paper\Paper_081.jpg
# Processing image 84...
# Saved: ./preprocessed_images\train\Paper\Paper_084.jpg
# Processing image 87...
# Saved: ./preprocessed_images\train\Paper\Paper_087.jpg
# Processing image 90...
# Saved: ./preprocessed_images\train\Paper\Paper_090.jpg
# Processing image 93...
# Saved: ./preprocessed_images\train\Paper\Paper_093.jpg
# Processing image 96...
# Saved: ./preprocessed_images\train\Paper\Paper_096.jpg
# Processing image 99...
# Saved: ./preprocessed_images\train\Paper\Paper_099.jpg
# Processing image 102...
# Saved: ./preprocessed_images\train\Paper\Paper_102.jpg
# Processing image 105...
# Saved: ./preprocessed_images\train\Paper\Paper_105.jpg
# Processing image 108...
# Saved: ./preprocessed_images\train\Paper\Paper_108.jpg
# Processing image 111...
# Saved: ./preprocessed_images\train\Paper\Paper_111.jpg
# Processing image 114...
# Saved: ./preprocessed_images\train\Paper\Paper_114.jpg
# Processing image 117...
# Saved: ./preprocessed_images\train\Paper\Paper_117.jpg
# Processing image 120...
# Saved: ./preprocessed_images\train\Paper\Paper_120.jpg
# Processing image 123...
# Saved: ./preprocessed_images\train\Paper\Paper_123.jpg
# Processing image 126...
# Saved: ./preprocessed_images\train\Paper\Paper_126.jpg
# Processing image 129...
# Saved: ./preprocessed_images\train\Paper\Paper_129.jpg
# Processing image 132...
# Saved: ./preprocessed_images\train\Paper\Paper_132.jpg
# Processing image 135...
# Saved: ./preprocessed_images\train\Paper\Paper_135.jpg
# Processing image 138...
# Saved: ./preprocessed_images\train\Paper\Paper_138.jpg
# Processing image 141...
# Saved: ./preprocessed_images\train\Paper\Paper_141.jpg
# Processing image 144...
# Saved: ./preprocessed_images\train\Paper\Paper_144.jpg
# Processing image 147...
# Saved: ./preprocessed_images\train\Paper\Paper_147.jpg
# Processing image 150...
# Saved: ./preprocessed_images\train\Paper\Paper_150.jpg
# Processing image 153...
# Saved: ./preprocessed_images\train\Paper\Paper_153.jpg
# Processing image 156...
# Saved: ./preprocessed_images\train\Paper\Paper_156.jpg
# Processing image 159...
# Saved: ./preprocessed_images\train\Paper\Paper_159.jpg
# Processing image 162...
# Saved: ./preprocessed_images\train\Paper\Paper_162.jpg
# Processing image 165...
# Saved: ./preprocessed_images\train\Paper\Paper_165.jpg
# Processing image 168...
# Saved: ./preprocessed_images\train\Paper\Paper_168.jpg
# Processing image 171...
# Saved: ./preprocessed_images\train\Paper\Paper_171.jpg
# Processing image 174...
# Saved: ./preprocessed_images\train\Paper\Paper_174.jpg
# Processing image 177...
# Saved: ./preprocessed_images\train\Paper\Paper_177.jpg
# Processing image 180...
# Saved: ./preprocessed_images\train\Paper\Paper_180.jpg
# Processing image 183...
# Saved: ./preprocessed_images\train\Paper\Paper_183.jpg
# Processing image 186...
# Saved: ./preprocessed_images\train\Paper\Paper_186.jpg
# Processing image 189...
# Saved: ./preprocessed_images\train\Paper\Paper_189.jpg
# Batch 2 of train complete!
# Processing batch 3 of train...
# Processing image 0...
# Saved: ./preprocessed_images\train\Paper\Paper_000.jpg
# Processing image 4...
# Saved: ./preprocessed_images\train\Paper\Paper_004.jpg
# Processing image 8...
# Saved: ./preprocessed_images\train\Paper\Paper_008.jpg
# Processing image 12...
# Saved: ./preprocessed_images\train\Paper\Paper_012.jpg
# Processing image 16...
# Saved: ./preprocessed_images\train\Paper\Paper_016.jpg
# Processing image 20...
# Saved: ./preprocessed_images\train\Paper\Paper_020.jpg
# Processing image 24...
# Saved: ./preprocessed_images\train\Paper\Paper_024.jpg
# Processing image 28...
# Saved: ./preprocessed_images\train\Paper\Paper_028.jpg
# Processing image 32...
# Saved: ./preprocessed_images\train\Paper\Paper_032.jpg
# Processing image 36...
# Saved: ./preprocessed_images\train\Paper\Paper_036.jpg
# Processing image 40...
# Saved: ./preprocessed_images\train\Paper\Paper_040.jpg
# Processing image 44...
# Saved: ./preprocessed_images\train\Paper\Paper_044.jpg
# Processing image 48...
# Saved: ./preprocessed_images\train\Paper\Paper_048.jpg
# Processing image 52...
# Saved: ./preprocessed_images\train\Paper\Paper_052.jpg
# Processing image 56...
# Saved: ./preprocessed_images\train\Paper\Paper_056.jpg
# Processing image 60...
# Saved: ./preprocessed_images\train\Paper\Paper_060.jpg
# Processing image 64...
# Saved: ./preprocessed_images\train\Paper\Paper_064.jpg
# Processing image 68...
# Saved: ./preprocessed_images\train\Paper\Paper_068.jpg
# Processing image 72...
# Saved: ./preprocessed_images\train\Paper\Paper_072.jpg
# Processing image 76...
# Saved: ./preprocessed_images\train\Paper\Paper_076.jpg
# Processing image 80...
# Saved: ./preprocessed_images\train\Paper\Paper_080.jpg
# Processing image 84...
# Saved: ./preprocessed_images\train\Paper\Paper_084.jpg
# Processing image 88...
# Saved: ./preprocessed_images\train\Paper\Paper_088.jpg
# Processing image 92...
# Saved: ./preprocessed_images\train\Paper\Paper_092.jpg
# Processing image 96...
# Saved: ./preprocessed_images\train\Paper\Paper_096.jpg
# Processing image 100...
# Saved: ./preprocessed_images\train\Paper\Paper_100.jpg
# Processing image 104...
# Saved: ./preprocessed_images\train\Paper\Paper_104.jpg
# Processing image 108...
# Saved: ./preprocessed_images\train\Paper\Paper_108.jpg
# Processing image 112...
# Saved: ./preprocessed_images\train\Paper\Paper_112.jpg
# Processing image 116...
# Saved: ./preprocessed_images\train\Paper\Paper_116.jpg
# Processing image 120...
# Saved: ./preprocessed_images\train\Paper\Paper_120.jpg
# Processing image 124...
# Saved: ./preprocessed_images\train\Paper\Paper_124.jpg
# Processing image 128...
# Saved: ./preprocessed_images\train\Paper\Paper_128.jpg
# Processing image 132...
# Saved: ./preprocessed_images\train\Paper\Paper_132.jpg
# Processing image 136...
# Saved: ./preprocessed_images\train\Paper\Paper_136.jpg
# Processing image 140...
# Saved: ./preprocessed_images\train\Paper\Paper_140.jpg
# Processing image 144...
# Saved: ./preprocessed_images\train\Paper\Paper_144.jpg
# Processing image 148...
# Saved: ./preprocessed_images\train\Paper\Paper_148.jpg
# Processing image 152...
# Saved: ./preprocessed_images\train\Paper\Paper_152.jpg
# Processing image 156...
# Saved: ./preprocessed_images\train\Paper\Paper_156.jpg
# Processing image 160...
# Saved: ./preprocessed_images\train\Paper\Paper_160.jpg
# Processing image 164...
# Saved: ./preprocessed_images\train\Paper\Paper_164.jpg
# Processing image 168...
# Saved: ./preprocessed_images\train\Paper\Paper_168.jpg
# Processing image 172...
# Saved: ./preprocessed_images\train\Paper\Paper_172.jpg
# Processing image 176...
# Saved: ./preprocessed_images\train\Paper\Paper_176.jpg
# Processing image 180...
# Saved: ./preprocessed_images\train\Paper\Paper_180.jpg
# Processing image 184...
# Saved: ./preprocessed_images\train\Paper\Paper_184.jpg
# Processing image 188...
# Saved: ./preprocessed_images\train\Paper\Paper_188.jpg
# Processing image 192...
# Saved: ./preprocessed_images\train\Paper\Paper_192.jpg
# Processing image 196...
# Saved: ./preprocessed_images\train\Paper\Paper_196.jpg
# Processing image 200...
# Saved: ./preprocessed_images\train\Paper\Paper_200.jpg
# Processing image 204...
# Saved: ./preprocessed_images\train\Paper\Paper_204.jpg
# Processing image 208...
# Saved: ./preprocessed_images\train\Paper\Paper_208.jpg
# Processing image 212...
# Saved: ./preprocessed_images\train\Paper\Paper_212.jpg
# Processing image 216...
# Saved: ./preprocessed_images\train\Paper\Paper_216.jpg
# Processing image 220...
# Saved: ./preprocessed_images\train\Paper\Paper_220.jpg
# Processing image 224...
# Saved: ./preprocessed_images\train\Paper\Paper_224.jpg
# Processing image 228...
# Saved: ./preprocessed_images\train\Paper\Paper_228.jpg
# Processing image 232...
# Saved: ./preprocessed_images\train\Paper\Paper_232.jpg
# Processing image 236...
# Saved: ./preprocessed_images\train\Paper\Paper_236.jpg
# Processing image 240...
# Saved: ./preprocessed_images\train\Paper\Paper_240.jpg
# Processing image 244...
# Saved: ./preprocessed_images\train\Paper\Paper_244.jpg
# Processing image 248...
# Saved: ./preprocessed_images\train\Paper\Paper_248.jpg
# Processing image 252...
# Saved: ./preprocessed_images\train\Paper\Paper_252.jpg
# Batch 3 of train complete!
# Processing batch 4 of train...
# Processing image 0...
# Saved: ./preprocessed_images\train\Paper\Paper_000.jpg
# Processing image 5...
# Saved: ./preprocessed_images\train\Paper\Paper_005.jpg
# Processing image 10...
# Saved: ./preprocessed_images\train\Paper\Paper_010.jpg
# Processing image 15...
# Saved: ./preprocessed_images\train\Paper\Paper_015.jpg
# Processing image 20...
# Saved: ./preprocessed_images\train\Paper\Paper_020.jpg
# Processing image 25...
# Saved: ./preprocessed_images\train\Paper\Paper_025.jpg
# Processing image 30...
# Saved: ./preprocessed_images\train\Paper\Paper_030.jpg
# Processing image 35...
# Saved: ./preprocessed_images\train\Paper\Paper_035.jpg
# Processing image 40...
# Saved: ./preprocessed_images\train\Paper\Paper_040.jpg
# Processing image 45...
# Saved: ./preprocessed_images\train\Paper\Paper_045.jpg
# Processing image 50...
# Saved: ./preprocessed_images\train\Paper\Paper_050.jpg
# Processing image 55...
# Saved: ./preprocessed_images\train\Paper\Paper_055.jpg
# Processing image 60...
# Saved: ./preprocessed_images\train\Paper\Paper_060.jpg
# Processing image 65...
# Saved: ./preprocessed_images\train\Paper\Paper_065.jpg
# Processing image 70...
# Saved: ./preprocessed_images\train\Paper\Paper_070.jpg
# Processing image 75...
# Saved: ./preprocessed_images\train\Paper\Paper_075.jpg
# Processing image 80...
# Saved: ./preprocessed_images\train\Paper\Paper_080.jpg
# Processing image 85...
# Saved: ./preprocessed_images\train\Paper\Paper_085.jpg
# Processing image 90...
# Saved: ./preprocessed_images\train\Paper\Paper_090.jpg
# Processing image 95...
# Saved: ./preprocessed_images\train\Paper\Paper_095.jpg
# Processing image 100...
# Saved: ./preprocessed_images\train\Paper\Paper_100.jpg
# Processing image 105...
# Saved: ./preprocessed_images\train\Paper\Paper_105.jpg
# Processing image 110...
# Saved: ./preprocessed_images\train\Paper\Paper_110.jpg
# Processing image 115...
# Saved: ./preprocessed_images\train\Paper\Paper_115.jpg
# Batch 4 of train complete!
# Processing and saving images for class './augmented_images Rock'...
# Processing batch 0 of train...
# Processing image 0...
# Saved: ./preprocessed_images\train\Rock\Rock_000.jpg
# Processing image 1...
# Saved: ./preprocessed_images\train\Rock\Rock_001.jpg
# Processing image 2...
# Saved: ./preprocessed_images\train\Rock\Rock_002.jpg
# Processing image 3...
# Saved: ./preprocessed_images\train\Rock\Rock_003.jpg
# Processing image 4...
# Saved: ./preprocessed_images\train\Rock\Rock_004.jpg
# Processing image 5...
# Saved: ./preprocessed_images\train\Rock\Rock_005.jpg
# Processing image 6...
# Saved: ./preprocessed_images\train\Rock\Rock_006.jpg
# Processing image 7...
# Saved: ./preprocessed_images\train\Rock\Rock_007.jpg
# Processing image 8...
# Saved: ./preprocessed_images\train\Rock\Rock_008.jpg
# Processing image 9...
# Saved: ./preprocessed_images\train\Rock\Rock_009.jpg
# Processing image 10...
# Saved: ./preprocessed_images\train\Rock\Rock_010.jpg
# Processing image 11...
# Saved: ./preprocessed_images\train\Rock\Rock_011.jpg
# Processing image 12...
# Saved: ./preprocessed_images\train\Rock\Rock_012.jpg
# Processing image 13...
# Saved: ./preprocessed_images\train\Rock\Rock_013.jpg
# Processing image 14...
# Saved: ./preprocessed_images\train\Rock\Rock_014.jpg
# Processing image 15...
# Saved: ./preprocessed_images\train\Rock\Rock_015.jpg
# Processing image 16...
# Saved: ./preprocessed_images\train\Rock\Rock_016.jpg
# Processing image 17...
# Saved: ./preprocessed_images\train\Rock\Rock_017.jpg
# Processing image 18...
# Saved: ./preprocessed_images\train\Rock\Rock_018.jpg
# Processing image 19...
# Saved: ./preprocessed_images\train\Rock\Rock_019.jpg
# Processing image 20...
# Saved: ./preprocessed_images\train\Rock\Rock_020.jpg
# Processing image 21...
# Saved: ./preprocessed_images\train\Rock\Rock_021.jpg
# Processing image 22...
# Saved: ./preprocessed_images\train\Rock\Rock_022.jpg
# Processing image 23...
# Saved: ./preprocessed_images\train\Rock\Rock_023.jpg
# Processing image 24...
# Saved: ./preprocessed_images\train\Rock\Rock_024.jpg
# Processing image 25...
# Saved: ./preprocessed_images\train\Rock\Rock_025.jpg
# Processing image 26...
# Saved: ./preprocessed_images\train\Rock\Rock_026.jpg
# Processing image 27...
# Saved: ./preprocessed_images\train\Rock\Rock_027.jpg
# Processing image 28...
# Saved: ./preprocessed_images\train\Rock\Rock_028.jpg
# Processing image 29...
# Saved: ./preprocessed_images\train\Rock\Rock_029.jpg
# Processing image 30...
# Saved: ./preprocessed_images\train\Rock\Rock_030.jpg
# Processing image 31...
# Saved: ./preprocessed_images\train\Rock\Rock_031.jpg
# Processing image 32...
# Saved: ./preprocessed_images\train\Rock\Rock_032.jpg
# Processing image 33...
# Saved: ./preprocessed_images\train\Rock\Rock_033.jpg
# Processing image 34...
# Saved: ./preprocessed_images\train\Rock\Rock_034.jpg
# Processing image 35...
# Saved: ./preprocessed_images\train\Rock\Rock_035.jpg
# Processing image 36...
# Saved: ./preprocessed_images\train\Rock\Rock_036.jpg
# Processing image 37...
# Saved: ./preprocessed_images\train\Rock\Rock_037.jpg
# Processing image 38...
# Saved: ./preprocessed_images\train\Rock\Rock_038.jpg
# Processing image 39...
# Saved: ./preprocessed_images\train\Rock\Rock_039.jpg
# Processing image 40...
# Saved: ./preprocessed_images\train\Rock\Rock_040.jpg
# Processing image 41...
# Saved: ./preprocessed_images\train\Rock\Rock_041.jpg
# Processing image 42...
# Saved: ./preprocessed_images\train\Rock\Rock_042.jpg
# Processing image 43...
# Saved: ./preprocessed_images\train\Rock\Rock_043.jpg
# Processing image 44...
# Saved: ./preprocessed_images\train\Rock\Rock_044.jpg
# Processing image 45...
# Saved: ./preprocessed_images\train\Rock\Rock_045.jpg
# Processing image 46...
# Saved: ./preprocessed_images\train\Rock\Rock_046.jpg
# Processing image 47...
# Saved: ./preprocessed_images\train\Rock\Rock_047.jpg
# Processing image 48...
# Saved: ./preprocessed_images\train\Rock\Rock_048.jpg
# Processing image 49...
# Saved: ./preprocessed_images\train\Rock\Rock_049.jpg
# Processing image 50...
# Saved: ./preprocessed_images\train\Rock\Rock_050.jpg
# Processing image 51...
# Saved: ./preprocessed_images\train\Rock\Rock_051.jpg
# Processing image 52...
# Saved: ./preprocessed_images\train\Rock\Rock_052.jpg
# Processing image 53...
# Saved: ./preprocessed_images\train\Rock\Rock_053.jpg
# Processing image 54...
# Saved: ./preprocessed_images\train\Rock\Rock_054.jpg
# Processing image 55...
# Saved: ./preprocessed_images\train\Rock\Rock_055.jpg
# Processing image 56...
# Saved: ./preprocessed_images\train\Rock\Rock_056.jpg
# Processing image 57...
# Saved: ./preprocessed_images\train\Rock\Rock_057.jpg
# Processing image 58...
# Saved: ./preprocessed_images\train\Rock\Rock_058.jpg
# Processing image 59...
# Saved: ./preprocessed_images\train\Rock\Rock_059.jpg
# Processing image 60...
# Saved: ./preprocessed_images\train\Rock\Rock_060.jpg
# Processing image 61...
# Saved: ./preprocessed_images\train\Rock\Rock_061.jpg
# Processing image 62...
# Saved: ./preprocessed_images\train\Rock\Rock_062.jpg
# Processing image 63...
# Saved: ./preprocessed_images\train\Rock\Rock_063.jpg
# Batch 0 of train complete!
# Processing batch 1 of train...
# Processing image 0...
# Saved: ./preprocessed_images\train\Rock\Rock_000.jpg
# Processing image 2...
# Saved: ./preprocessed_images\train\Rock\Rock_002.jpg
# Processing image 4...
# Saved: ./preprocessed_images\train\Rock\Rock_004.jpg
# Processing image 6...
# Saved: ./preprocessed_images\train\Rock\Rock_006.jpg
# Processing image 8...
# Saved: ./preprocessed_images\train\Rock\Rock_008.jpg
# Processing image 10...
# Saved: ./preprocessed_images\train\Rock\Rock_010.jpg
# Processing image 12...
# Saved: ./preprocessed_images\train\Rock\Rock_012.jpg
# Processing image 14...
# Saved: ./preprocessed_images\train\Rock\Rock_014.jpg
# Processing image 16...
# Saved: ./preprocessed_images\train\Rock\Rock_016.jpg
# Processing image 18...
# Saved: ./preprocessed_images\train\Rock\Rock_018.jpg
# Processing image 20...
# Saved: ./preprocessed_images\train\Rock\Rock_020.jpg
# Processing image 22...
# Saved: ./preprocessed_images\train\Rock\Rock_022.jpg
# Processing image 24...
# Saved: ./preprocessed_images\train\Rock\Rock_024.jpg
# Processing image 26...
# Saved: ./preprocessed_images\train\Rock\Rock_026.jpg
# Processing image 28...
# Saved: ./preprocessed_images\train\Rock\Rock_028.jpg
# Processing image 30...
# Saved: ./preprocessed_images\train\Rock\Rock_030.jpg
# Processing image 32...
# Saved: ./preprocessed_images\train\Rock\Rock_032.jpg
# Processing image 34...
# Saved: ./preprocessed_images\train\Rock\Rock_034.jpg
# Processing image 36...
# Saved: ./preprocessed_images\train\Rock\Rock_036.jpg
# Processing image 38...
# Saved: ./preprocessed_images\train\Rock\Rock_038.jpg
# Processing image 40...
# Saved: ./preprocessed_images\train\Rock\Rock_040.jpg
# Processing image 42...
# Saved: ./preprocessed_images\train\Rock\Rock_042.jpg
# Processing image 44...
# Saved: ./preprocessed_images\train\Rock\Rock_044.jpg
# Processing image 46...
# Saved: ./preprocessed_images\train\Rock\Rock_046.jpg
# Processing image 48...
# Saved: ./preprocessed_images\train\Rock\Rock_048.jpg
# Processing image 50...
# Saved: ./preprocessed_images\train\Rock\Rock_050.jpg
# Processing image 52...
# Saved: ./preprocessed_images\train\Rock\Rock_052.jpg
# Processing image 54...
# Saved: ./preprocessed_images\train\Rock\Rock_054.jpg
# Processing image 56...
# Saved: ./preprocessed_images\train\Rock\Rock_056.jpg
# Processing image 58...
# Saved: ./preprocessed_images\train\Rock\Rock_058.jpg
# Processing image 60...
# Saved: ./preprocessed_images\train\Rock\Rock_060.jpg
# Processing image 62...
# Saved: ./preprocessed_images\train\Rock\Rock_062.jpg
# Processing image 64...
# Saved: ./preprocessed_images\train\Rock\Rock_064.jpg
# Processing image 66...
# Saved: ./preprocessed_images\train\Rock\Rock_066.jpg
# Processing image 68...
# Saved: ./preprocessed_images\train\Rock\Rock_068.jpg
# Processing image 70...
# Saved: ./preprocessed_images\train\Rock\Rock_070.jpg
# Processing image 72...
# Saved: ./preprocessed_images\train\Rock\Rock_072.jpg
# Processing image 74...
# Saved: ./preprocessed_images\train\Rock\Rock_074.jpg
# Processing image 76...
# Saved: ./preprocessed_images\train\Rock\Rock_076.jpg
# Processing image 78...
# Saved: ./preprocessed_images\train\Rock\Rock_078.jpg
# Processing image 80...
# Saved: ./preprocessed_images\train\Rock\Rock_080.jpg
# Processing image 82...
# Saved: ./preprocessed_images\train\Rock\Rock_082.jpg
# Processing image 84...
# Saved: ./preprocessed_images\train\Rock\Rock_084.jpg
# Processing image 86...
# Saved: ./preprocessed_images\train\Rock\Rock_086.jpg
# Processing image 88...
# Saved: ./preprocessed_images\train\Rock\Rock_088.jpg
# Processing image 90...
# Saved: ./preprocessed_images\train\Rock\Rock_090.jpg
# Processing image 92...
# Saved: ./preprocessed_images\train\Rock\Rock_092.jpg
# Processing image 94...
# Saved: ./preprocessed_images\train\Rock\Rock_094.jpg
# Processing image 96...
# Saved: ./preprocessed_images\train\Rock\Rock_096.jpg
# Processing image 98...
# Saved: ./preprocessed_images\train\Rock\Rock_098.jpg
# Processing image 100...
# Saved: ./preprocessed_images\train\Rock\Rock_100.jpg
# Processing image 102...
# Saved: ./preprocessed_images\train\Rock\Rock_102.jpg
# Processing image 104...
# Saved: ./preprocessed_images\train\Rock\Rock_104.jpg
# Processing image 106...
# Saved: ./preprocessed_images\train\Rock\Rock_106.jpg
# Processing image 108...
# Saved: ./preprocessed_images\train\Rock\Rock_108.jpg
# Processing image 110...
# Saved: ./preprocessed_images\train\Rock\Rock_110.jpg
# Processing image 112...
# Saved: ./preprocessed_images\train\Rock\Rock_112.jpg
# Processing image 114...
# Saved: ./preprocessed_images\train\Rock\Rock_114.jpg
# Processing image 116...
# Saved: ./preprocessed_images\train\Rock\Rock_116.jpg
# Processing image 118...
# Saved: ./preprocessed_images\train\Rock\Rock_118.jpg
# Processing image 120...
# Saved: ./preprocessed_images\train\Rock\Rock_120.jpg
# Processing image 122...
# Saved: ./preprocessed_images\train\Rock\Rock_122.jpg
# Processing image 124...
# Saved: ./preprocessed_images\train\Rock\Rock_124.jpg
# Processing image 126...
# Saved: ./preprocessed_images\train\Rock\Rock_126.jpg
# Batch 1 of train complete!
# Processing batch 2 of train...
# Processing image 0...
# Saved: ./preprocessed_images\train\Rock\Rock_000.jpg
# Processing image 3...
# Saved: ./preprocessed_images\train\Rock\Rock_003.jpg
# Processing image 6...
# Saved: ./preprocessed_images\train\Rock\Rock_006.jpg
# Processing image 9...
# Saved: ./preprocessed_images\train\Rock\Rock_009.jpg
# Processing image 12...
# Saved: ./preprocessed_images\train\Rock\Rock_012.jpg
# Processing image 15...
# Saved: ./preprocessed_images\train\Rock\Rock_015.jpg
# Processing image 18...
# Saved: ./preprocessed_images\train\Rock\Rock_018.jpg
# Processing image 21...
# Saved: ./preprocessed_images\train\Rock\Rock_021.jpg
# Processing image 24...
# Saved: ./preprocessed_images\train\Rock\Rock_024.jpg
# Processing image 27...
# Saved: ./preprocessed_images\train\Rock\Rock_027.jpg
# Processing image 30...
# Saved: ./preprocessed_images\train\Rock\Rock_030.jpg
# Processing image 33...
# Saved: ./preprocessed_images\train\Rock\Rock_033.jpg
# Processing image 36...
# Saved: ./preprocessed_images\train\Rock\Rock_036.jpg
# Processing image 39...
# Saved: ./preprocessed_images\train\Rock\Rock_039.jpg
# Processing image 42...
# Saved: ./preprocessed_images\train\Rock\Rock_042.jpg
# Processing image 45...
# Saved: ./preprocessed_images\train\Rock\Rock_045.jpg
# Processing image 48...
# Saved: ./preprocessed_images\train\Rock\Rock_048.jpg
# Processing image 51...
# Saved: ./preprocessed_images\train\Rock\Rock_051.jpg
# Processing image 54...
# Saved: ./preprocessed_images\train\Rock\Rock_054.jpg
# Processing image 57...
# Saved: ./preprocessed_images\train\Rock\Rock_057.jpg
# Processing image 60...
# Saved: ./preprocessed_images\train\Rock\Rock_060.jpg
# Processing image 63...
# Saved: ./preprocessed_images\train\Rock\Rock_063.jpg
# Processing image 66...
# Saved: ./preprocessed_images\train\Rock\Rock_066.jpg
# Processing image 69...
# Saved: ./preprocessed_images\train\Rock\Rock_069.jpg
# Processing image 72...
# Saved: ./preprocessed_images\train\Rock\Rock_072.jpg
# Processing image 75...
# Saved: ./preprocessed_images\train\Rock\Rock_075.jpg
# Processing image 78...
# Saved: ./preprocessed_images\train\Rock\Rock_078.jpg
# Processing image 81...
# Saved: ./preprocessed_images\train\Rock\Rock_081.jpg
# Processing image 84...
# Saved: ./preprocessed_images\train\Rock\Rock_084.jpg
# Processing image 87...
# Saved: ./preprocessed_images\train\Rock\Rock_087.jpg
# Processing image 90...
# Saved: ./preprocessed_images\train\Rock\Rock_090.jpg
# Processing image 93...
# Saved: ./preprocessed_images\train\Rock\Rock_093.jpg
# Processing image 96...
# Saved: ./preprocessed_images\train\Rock\Rock_096.jpg
# Processing image 99...
# Saved: ./preprocessed_images\train\Rock\Rock_099.jpg
# Processing image 102...
# Saved: ./preprocessed_images\train\Rock\Rock_102.jpg
# Processing image 105...
# Saved: ./preprocessed_images\train\Rock\Rock_105.jpg
# Processing image 108...
# Saved: ./preprocessed_images\train\Rock\Rock_108.jpg
# Processing image 111...
# Saved: ./preprocessed_images\train\Rock\Rock_111.jpg
# Processing image 114...
# Saved: ./preprocessed_images\train\Rock\Rock_114.jpg
# Processing image 117...
# Saved: ./preprocessed_images\train\Rock\Rock_117.jpg
# Processing image 120...
# Saved: ./preprocessed_images\train\Rock\Rock_120.jpg
# Processing image 123...
# Saved: ./preprocessed_images\train\Rock\Rock_123.jpg
# Processing image 126...
# Saved: ./preprocessed_images\train\Rock\Rock_126.jpg
# Processing image 129...
# Saved: ./preprocessed_images\train\Rock\Rock_129.jpg
# Processing image 132...
# Saved: ./preprocessed_images\train\Rock\Rock_132.jpg
# Processing image 135...
# Saved: ./preprocessed_images\train\Rock\Rock_135.jpg
# Processing image 138...
# Saved: ./preprocessed_images\train\Rock\Rock_138.jpg
# Processing image 141...
# Saved: ./preprocessed_images\train\Rock\Rock_141.jpg
# Processing image 144...
# Saved: ./preprocessed_images\train\Rock\Rock_144.jpg
# Processing image 147...
# Saved: ./preprocessed_images\train\Rock\Rock_147.jpg
# Processing image 150...
# Saved: ./preprocessed_images\train\Rock\Rock_150.jpg
# Processing image 153...
# Saved: ./preprocessed_images\train\Rock\Rock_153.jpg
# Processing image 156...
# Saved: ./preprocessed_images\train\Rock\Rock_156.jpg
# Processing image 159...
# Saved: ./preprocessed_images\train\Rock\Rock_159.jpg
# Processing image 162...
# Saved: ./preprocessed_images\train\Rock\Rock_162.jpg
# Processing image 165...
# Saved: ./preprocessed_images\train\Rock\Rock_165.jpg
# Processing image 168...
# Saved: ./preprocessed_images\train\Rock\Rock_168.jpg
# Processing image 171...
# Saved: ./preprocessed_images\train\Rock\Rock_171.jpg
# Processing image 174...
# Saved: ./preprocessed_images\train\Rock\Rock_174.jpg
# Processing image 177...
# Saved: ./preprocessed_images\train\Rock\Rock_177.jpg
# Processing image 180...
# Saved: ./preprocessed_images\train\Rock\Rock_180.jpg
# Processing image 183...
# Saved: ./preprocessed_images\train\Rock\Rock_183.jpg
# Processing image 186...
# Saved: ./preprocessed_images\train\Rock\Rock_186.jpg
# Processing image 189...
# Saved: ./preprocessed_images\train\Rock\Rock_189.jpg
# Batch 2 of train complete!
# Processing batch 3 of train...
# Processing image 0...
# Saved: ./preprocessed_images\train\Rock\Rock_000.jpg
# Processing image 4...
# Saved: ./preprocessed_images\train\Rock\Rock_004.jpg
# Processing image 8...
# ...
# Processing image 36...
# Saved: ./preprocessed_images\train\Scissor\Scissor_036.jpg
# Processing image 38...
# Saved: ./preprocessed_images\train\Scissor\Scissor_038.jpg
# Processing image 40...
# Saved: ./preprocessed_images\train\Scissor\Scissor_040.jpg
# Processing image 42...
# Saved: ./preprocessed_images\train\Scissor\Scissor_042.jpg
# Processing image 44...
# Saved: ./preprocessed_images\train\Scissor\Scissor_044.jpg
# Processing image 46...
# Saved: ./preprocessed_images\train\Scissor\Scissor_046.jpg
# Processing image 48...
# Saved: ./preprocessed_images\train\Scissor\Scissor_048.jpg
# Processing image 50...
# Saved: ./preprocessed_images\train\Scissor\Scissor_050.jpg
# Processing image 52...
# Saved: ./preprocessed_images\train\Scissor\Scissor_052.jpg
# Processing image 54...
# Saved: ./preprocessed_images\train\Scissor\Scissor_054.jpg
# Processing image 56...
# Saved: ./preprocessed_images\train\Scissor\Scissor_056.jpg
# Processing image 58...
# Saved: ./preprocessed_images\train\Scissor\Scissor_058.jpg
# Processing image 60...
# Saved: ./preprocessed_images\train\Scissor\Scissor_060.jpg
# Processing image 62...
# Saved: ./preprocessed_images\train\Scissor\Scissor_062.jpg
# Processing image 64...
# Saved: ./preprocessed_images\train\Scissor\Scissor_064.jpg
# Processing image 66...
# Saved: ./preprocessed_images\train\Scissor\Scissor_066.jpg
# Processing image 68...
# Saved: ./preprocessed_images\train\Scissor\Scissor_068.jpg
# Processing image 70...
# Saved: ./preprocessed_images\train\Scissor\Scissor_070.jpg
# Processing image 72...
# Saved: ./preprocessed_images\train\Scissor\Scissor_072.jpg
# Processing image 74...
# Saved: ./preprocessed_images\train\Scissor\Scissor_074.jpg
# Processing image 76...
# Saved: ./preprocessed_images\train\Scissor\Scissor_076.jpg
# Processing image 78...
# Saved: ./preprocessed_images\train\Scissor\Scissor_078.jpg
# Processing image 80...
# Saved: ./preprocessed_images\train\Scissor\Scissor_080.jpg
# Processing image 82...
# Saved: ./preprocessed_images\train\Scissor\Scissor_082.jpg
# Processing image 84...
# Saved: ./preprocessed_images\train\Scissor\Scissor_084.jpg
# Processing image 86...
# Saved: ./preprocessed_images\train\Scissor\Scissor_086.jpg
# Processing image 88...
# Saved: ./preprocessed_images\train\Scissor\Scissor_088.jpg
# Processing image 90...
# Saved: ./preprocessed_images\train\Scissor\Scissor_090.jpg
# Processing image 92...
# Saved: ./preprocessed_images\train\Scissor\Scissor_092.jpg
# Processing image 94...
# Saved: ./preprocessed_images\train\Scissor\Scissor_094.jpg
# Processing image 96...
# Saved: ./preprocessed_images\train\Scissor\Scissor_096.jpg
# Processing image 98...
# Saved: ./preprocessed_images\train\Scissor\Scissor_098.jpg
# Processing image 100...
# Saved: ./preprocessed_images\train\Scissor\Scissor_100.jpg
# Processing image 102...
# Saved: ./preprocessed_images\train\Scissor\Scissor_102.jpg
# Processing image 104...
# Saved: ./preprocessed_images\train\Scissor\Scissor_104.jpg
# Processing image 106...
# Saved: ./preprocessed_images\train\Scissor\Scissor_106.jpg
# Processing image 108...
# Saved: ./preprocessed_images\train\Scissor\Scissor_108.jpg
# Processing image 110...
# Saved: ./preprocessed_images\train\Scissor\Scissor_110.jpg
# Processing image 112...
# Saved: ./preprocessed_images\train\Scissor\Scissor_112.jpg
# Processing image 114...
# Saved: ./preprocessed_images\train\Scissor\Scissor_114.jpg
# Processing image 116...
# Saved: ./preprocessed_images\train\Scissor\Scissor_116.jpg
# Processing image 118...
# Saved: ./preprocessed_images\train\Scissor\Scissor_118.jpg
# Processing image 120...
# Saved: ./preprocessed_images\train\Scissor\Scissor_120.jpg
# Processing image 122...
# Saved: ./preprocessed_images\train\Scissor\Scissor_122.jpg
# Processing image 124...
# Saved: ./preprocessed_images\train\Scissor\Scissor_124.jpg
# Processing image 126...
# Saved: ./preprocessed_images\train\Scissor\Scissor_126.jpg
# Batch 1 of train complete!
# Processing batch 2 of train...
# Processing image 0...
# Saved: ./preprocessed_images\train\Scissor\Scissor_000.jpg
# Processing image 3...
# Saved: ./preprocessed_images\train\Scissor\Scissor_003.jpg
# Processing image 6...
# Saved: ./preprocessed_images\train\Scissor\Scissor_006.jpg
# Processing image 9...
# Saved: ./preprocessed_images\train\Scissor\Scissor_009.jpg
# Processing image 12...
# Saved: ./preprocessed_images\train\Scissor\Scissor_012.jpg
# Processing image 15...
# Saved: ./preprocessed_images\train\Scissor\Scissor_015.jpg
# Processing image 18...
# Saved: ./preprocessed_images\train\Scissor\Scissor_018.jpg
# Processing image 21...
# Saved: ./preprocessed_images\train\Scissor\Scissor_021.jpg
# Processing image 24...
# Saved: ./preprocessed_images\train\Scissor\Scissor_024.jpg
# Processing image 27...
# Saved: ./preprocessed_images\train\Scissor\Scissor_027.jpg
# Processing image 30...
# Saved: ./preprocessed_images\train\Scissor\Scissor_030.jpg
# Processing image 33...
# Saved: ./preprocessed_images\train\Scissor\Scissor_033.jpg
# Processing image 36...
# Saved: ./preprocessed_images\train\Scissor\Scissor_036.jpg
# Processing image 39...
# Saved: ./preprocessed_images\train\Scissor\Scissor_039.jpg
# Processing image 42...
# Saved: ./preprocessed_images\train\Scissor\Scissor_042.jpg
# Processing image 45...
# Saved: ./preprocessed_images\train\Scissor\Scissor_045.jpg
# Processing image 48...
# Saved: ./preprocessed_images\train\Scissor\Scissor_048.jpg
# Processing image 51...
# Saved: ./preprocessed_images\train\Scissor\Scissor_051.jpg
# Processing image 54...
# Saved: ./preprocessed_images\train\Scissor\Scissor_054.jpg
# Processing image 57...
# Saved: ./preprocessed_images\train\Scissor\Scissor_057.jpg
# Processing image 60...
# Saved: ./preprocessed_images\train\Scissor\Scissor_060.jpg
# Processing image 63...
# Saved: ./preprocessed_images\train\Scissor\Scissor_063.jpg
# Processing image 66...
# Saved: ./preprocessed_images\train\Scissor\Scissor_066.jpg
# Processing image 69...
# Saved: ./preprocessed_images\train\Scissor\Scissor_069.jpg
# Processing image 72...
# Saved: ./preprocessed_images\train\Scissor\Scissor_072.jpg
# Processing image 75...
# Saved: ./preprocessed_images\train\Scissor\Scissor_075.jpg
# Processing image 78...
# Saved: ./preprocessed_images\train\Scissor\Scissor_078.jpg
# Processing image 81...
# Saved: ./preprocessed_images\train\Scissor\Scissor_081.jpg
# Processing image 84...
# Saved: ./preprocessed_images\train\Scissor\Scissor_084.jpg
# Processing image 87...
# Saved: ./preprocessed_images\train\Scissor\Scissor_087.jpg
# Processing image 90...
# Saved: ./preprocessed_images\train\Scissor\Scissor_090.jpg
# Processing image 93...
# Saved: ./preprocessed_images\train\Scissor\Scissor_093.jpg
# Processing image 96...
# Saved: ./preprocessed_images\train\Scissor\Scissor_096.jpg
# Processing image 99...
# Saved: ./preprocessed_images\train\Scissor\Scissor_099.jpg
# Processing image 102...
# Saved: ./preprocessed_images\train\Scissor\Scissor_102.jpg
# Processing image 105...
# Saved: ./preprocessed_images\train\Scissor\Scissor_105.jpg
# Processing image 108...
# Saved: ./preprocessed_images\train\Scissor\Scissor_108.jpg
# Processing image 111...
# Saved: ./preprocessed_images\train\Scissor\Scissor_111.jpg
# Processing image 114...
# Saved: ./preprocessed_images\train\Scissor\Scissor_114.jpg
# Processing image 117...
# Saved: ./preprocessed_images\train\Scissor\Scissor_117.jpg
# Processing image 120...
# Saved: ./preprocessed_images\train\Scissor\Scissor_120.jpg
# Processing image 123...
# Saved: ./preprocessed_images\train\Scissor\Scissor_123.jpg
# Processing image 126...
# Saved: ./preprocessed_images\train\Scissor\Scissor_126.jpg
# Processing image 129...
# Saved: ./preprocessed_images\train\Scissor\Scissor_129.jpg
# Processing image 132...
# Saved: ./preprocessed_images\train\Scissor\Scissor_132.jpg
# Processing image 135...
# Saved: ./preprocessed_images\train\Scissor\Scissor_135.jpg
# Processing image 138...
# Saved: ./preprocessed_images\train\Scissor\Scissor_138.jpg
# Processing image 141...
# Saved: ./preprocessed_images\train\Scissor\Scissor_141.jpg
# Processing image 144...
# Saved: ./preprocessed_images\train\Scissor\Scissor_144.jpg
# Processing image 147...
# Saved: ./preprocessed_images\train\Scissor\Scissor_147.jpg
# Processing image 150...
# Saved: ./preprocessed_images\train\Scissor\Scissor_150.jpg
# Processing image 153...
# Saved: ./preprocessed_images\train\Scissor\Scissor_153.jpg
# Processing image 156...
# Saved: ./preprocessed_images\train\Scissor\Scissor_156.jpg
# Processing image 159...
# Saved: ./preprocessed_images\train\Scissor\Scissor_159.jpg
# Processing image 162...
# Saved: ./preprocessed_images\train\Scissor\Scissor_162.jpg
# Processing image 165...
# Saved: ./preprocessed_images\train\Scissor\Scissor_165.jpg
# Processing image 168...
# Saved: ./preprocessed_images\train\Scissor\Scissor_168.jpg
# Processing image 171...
# Saved: ./preprocessed_images\train\Scissor\Scissor_171.jpg
# Processing image 174...
# Saved: ./preprocessed_images\train\Scissor\Scissor_174.jpg
# Processing image 177...
# Saved: ./preprocessed_images\train\Scissor\Scissor_177.jpg
# Processing image 180...
# Saved: ./preprocessed_images\train\Scissor\Scissor_180.jpg
# Processing image 183...
# Saved: ./preprocessed_images\train\Scissor\Scissor_183.jpg
# Processing image 186...
# Saved: ./preprocessed_images\train\Scissor\Scissor_186.jpg
# Processing image 189...
# Saved: ./preprocessed_images\train\Scissor\Scissor_189.jpg
# Batch 2 of train complete!
# Processing batch 3 of train...
# Processing image 0...
# Saved: ./preprocessed_images\train\Scissor\Scissor_000.jpg
# Processing image 4...
# Saved: ./preprocessed_images\train\Scissor\Scissor_004.jpg
# Processing image 8...
# Saved: ./preprocessed_images\train\Scissor\Scissor_008.jpg
# Processing image 12...
# Saved: ./preprocessed_images\train\Scissor\Scissor_012.jpg
# Processing image 16...
# Saved: ./preprocessed_images\train\Scissor\Scissor_016.jpg
# Processing image 20...
# Saved: ./preprocessed_images\train\Scissor\Scissor_020.jpg
# Processing image 24...
# Saved: ./preprocessed_images\train\Scissor\Scissor_024.jpg
# Processing image 28...
# Saved: ./preprocessed_images\train\Scissor\Scissor_028.jpg
# Processing image 32...
# Saved: ./preprocessed_images\train\Scissor\Scissor_032.jpg
# Processing image 36...
# Saved: ./preprocessed_images\train\Scissor\Scissor_036.jpg
# Processing image 40...
# Saved: ./preprocessed_images\train\Scissor\Scissor_040.jpg
# Processing image 44...
# Saved: ./preprocessed_images\train\Scissor\Scissor_044.jpg
# Processing image 48...
# Saved: ./preprocessed_images\train\Scissor\Scissor_048.jpg
# Processing image 52...
# Saved: ./preprocessed_images\train\Scissor\Scissor_052.jpg
# Processing image 56...
# Saved: ./preprocessed_images\train\Scissor\Scissor_056.jpg
# Processing image 60...
# Saved: ./preprocessed_images\train\Scissor\Scissor_060.jpg
# Processing image 64...
# Saved: ./preprocessed_images\train\Scissor\Scissor_064.jpg
# Processing image 68...
# Saved: ./preprocessed_images\train\Scissor\Scissor_068.jpg
# Processing image 72...
# Saved: ./preprocessed_images\train\Scissor\Scissor_072.jpg
# Processing image 76...
# Saved: ./preprocessed_images\train\Scissor\Scissor_076.jpg
# Processing image 80...
# Saved: ./preprocessed_images\train\Scissor\Scissor_080.jpg
# Processing image 84...
# Saved: ./preprocessed_images\train\Scissor\Scissor_084.jpg
# Processing image 88...
# Saved: ./preprocessed_images\train\Scissor\Scissor_088.jpg
# Processing image 92...
# Saved: ./preprocessed_images\train\Scissor\Scissor_092.jpg
# Processing image 96...
# Saved: ./preprocessed_images\train\Scissor\Scissor_096.jpg
# Processing image 100...
# Saved: ./preprocessed_images\train\Scissor\Scissor_100.jpg
# Processing image 104...
# Saved: ./preprocessed_images\train\Scissor\Scissor_104.jpg
# Processing image 108...
# Saved: ./preprocessed_images\train\Scissor\Scissor_108.jpg
# Processing image 112...
# Saved: ./preprocessed_images\train\Scissor\Scissor_112.jpg
# Processing image 116...
# Saved: ./preprocessed_images\train\Scissor\Scissor_116.jpg
# Processing image 120...
# Saved: ./preprocessed_images\train\Scissor\Scissor_120.jpg
# Processing image 124...
# Saved: ./preprocessed_images\train\Scissor\Scissor_124.jpg
# Processing image 128...
# Saved: ./preprocessed_images\train\Scissor\Scissor_128.jpg
# Processing image 132...
# Saved: ./preprocessed_images\train\Scissor\Scissor_132.jpg
# Processing image 136...
# Saved: ./preprocessed_images\train\Scissor\Scissor_136.jpg
# Processing image 140...
# Saved: ./preprocessed_images\train\Scissor\Scissor_140.jpg
# Processing image 144...
# Saved: ./preprocessed_images\train\Scissor\Scissor_144.jpg
# Processing image 148...
# Saved: ./preprocessed_images\train\Scissor\Scissor_148.jpg
# Processing image 152...
# Saved: ./preprocessed_images\train\Scissor\Scissor_152.jpg
# Processing image 156...
# Saved: ./preprocessed_images\train\Scissor\Scissor_156.jpg
# Processing image 160...
# Saved: ./preprocessed_images\train\Scissor\Scissor_160.jpg
# Processing image 164...
# Saved: ./preprocessed_images\train\Scissor\Scissor_164.jpg
# Processing image 168...
# Saved: ./preprocessed_images\train\Scissor\Scissor_168.jpg
# Processing image 172...
# Saved: ./preprocessed_images\train\Scissor\Scissor_172.jpg
# Processing image 176...
# Saved: ./preprocessed_images\train\Scissor\Scissor_176.jpg
# Processing image 180...
# Saved: ./preprocessed_images\train\Scissor\Scissor_180.jpg
# Processing image 184...
# Saved: ./preprocessed_images\train\Scissor\Scissor_184.jpg
# Processing image 188...
# Saved: ./preprocessed_images\train\Scissor\Scissor_188.jpg
# Processing image 192...
# Saved: ./preprocessed_images\train\Scissor\Scissor_192.jpg
# Processing image 196...
# Saved: ./preprocessed_images\train\Scissor\Scissor_196.jpg
# Processing image 200...
# Saved: ./preprocessed_images\train\Scissor\Scissor_200.jpg
# Processing image 204...
# Saved: ./preprocessed_images\train\Scissor\Scissor_204.jpg
# Processing image 208...
# Saved: ./preprocessed_images\train\Scissor\Scissor_208.jpg
# Processing image 212...
# Saved: ./preprocessed_images\train\Scissor\Scissor_212.jpg
# Processing image 216...
# Saved: ./preprocessed_images\train\Scissor\Scissor_216.jpg
# Processing image 220...
# Saved: ./preprocessed_images\train\Scissor\Scissor_220.jpg
# Processing image 224...
# Saved: ./preprocessed_images\train\Scissor\Scissor_224.jpg
# Processing image 228...
# Saved: ./preprocessed_images\train\Scissor\Scissor_228.jpg
# Processing image 232...
# Saved: ./preprocessed_images\train\Scissor\Scissor_232.jpg
# Processing image 236...
# Saved: ./preprocessed_images\train\Scissor\Scissor_236.jpg
# Processing image 240...
# Saved: ./preprocessed_images\train\Scissor\Scissor_240.jpg
# Processing image 244...
# Saved: ./preprocessed_images\train\Scissor\Scissor_244.jpg
# Processing image 248...
# Saved: ./preprocessed_images\train\Scissor\Scissor_248.jpg
# Processing image 252...
# Saved: ./preprocessed_images\train\Scissor\Scissor_252.jpg
# Batch 3 of train complete!
# Processing batch 4 of train...
# Processing image 0...
# Saved: ./preprocessed_images\train\Scissor\Scissor_000.jpg
# Processing image 5...
# Saved: ./preprocessed_images\train\Scissor\Scissor_005.jpg
# Processing image 10...
# Saved: ./preprocessed_images\train\Scissor\Scissor_010.jpg
# Processing image 15...
# Saved: ./preprocessed_images\train\Scissor\Scissor_015.jpg
# Processing image 20...
# Saved: ./preprocessed_images\train\Scissor\Scissor_020.jpg
# Processing image 25...
# Saved: ./preprocessed_images\train\Scissor\Scissor_025.jpg
# Processing image 30...
# Saved: ./preprocessed_images\train\Scissor\Scissor_030.jpg
# Processing image 35...
# Saved: ./preprocessed_images\train\Scissor\Scissor_035.jpg
# Processing image 40...
# Saved: ./preprocessed_images\train\Scissor\Scissor_040.jpg
# Processing image 45...
# Saved: ./preprocessed_images\train\Scissor\Scissor_045.jpg
# Processing image 50...
# Saved: ./preprocessed_images\train\Scissor\Scissor_050.jpg
# Processing image 55...
# Saved: ./preprocessed_images\train\Scissor\Scissor_055.jpg
# Processing image 60...
# Saved: ./preprocessed_images\train\Scissor\Scissor_060.jpg
# Processing image 65...
# Saved: ./preprocessed_images\train\Scissor\Scissor_065.jpg
# Processing image 70...
# Saved: ./preprocessed_images\train\Scissor\Scissor_070.jpg
# Processing image 75...
# Saved: ./preprocessed_images\train\Scissor\Scissor_075.jpg
# Processing image 80...
# Saved: ./preprocessed_images\train\Scissor\Scissor_080.jpg
# Batch 4 of train complete!
# Preprocessing complete!
