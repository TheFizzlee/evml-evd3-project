# %%
# Imports
import os
import shutil
from torchvision import transforms
from PIL import Image, ImageEnhance, ImageOps
import torch
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision.utils import save_image
from torchvision import datasets
from torch.utils.data import DataLoader
import warnings
import numpy as np
import cv2

# %%
# Variables
# Define directories
source_dirs = ['./images', './augmented_images']  # List of source directories containing your original and augmented images
output_dir = './preprocessed_images'  # Destination directory for preprocessed images

images_by_label = {}

labels = {}

batch_size = 64

# Suppress the DecompressionBombWarning
warnings.simplefilter('ignore', Image.DecompressionBombWarning)

# %%
# Locate all classes in the source directories
for source_dir in source_dirs:
    for class_name in os.listdir(source_dir):
        class_path = os.path.join(source_dir, class_name)
        if os.path.isdir(class_path):
            if class_name not in labels:
                labels[class_name] = []
            print(f'Found class {class_name} in {source_dir}')
# Out:
# Found class Paper in ./images
# Found class Rock in ./images
# Found class Scissor in ./images
# Found class Paper in ./augmented_images
# Found class Rock in ./augmented_images
# Found class Scissor in ./augmented_images

# %%
# Load the data
for source_dir in source_dirs:
    for class_name in os.listdir(source_dir):
        class_path = os.path.join(source_dir, class_name)
        if not os.path.isdir(class_path):
            continue  # Skip if not a directory

        # Initialize list for the class if not already present
        if class_name not in images_by_label:
            images_by_label[class_name] = []

        # Traverse images in the class folder
        for file_name in os.listdir(class_path):
            if file_name.endswith(('.png', '.jpg', '.jpeg')):  # Check for valid image extensions
                file_path = os.path.join(class_path, file_name)

                # Load the image
                image = Image.open(file_path)

                # Append the image to the corresponding label's list
                images_by_label[class_name].append(image)

# Print summary
for label, images in images_by_label.items():
    print(f"Loaded {len(images)} images for label '{label}'.")
# Out:
# Loaded 320 images for label 'Paper'.
# Loaded 432 images for label 'Rock'.
# Loaded 312 images for label 'Scissor'.

# %%
def resize_with_aspect_ratio(image, size):
    # Resize the image while maintaining the aspect ratio
    wpercent = (size / float(image.size[0]))
    hsize = int((float(image.size[1]) * float(wpercent)))
    img = image.resize((size, hsize), Image.Resampling.LANCZOS)
    return img

# %%
def auto_exposure(img):
    # Convert the image to a numpy array
    img_array = np.array(img)

    # Split into R, G, B channels
    r, g, b = cv2.split(img_array)

    # Apply CLAHE to each channel
    clahe = cv2.createCLAHE(clipLimit=25.0, tileGridSize=(8, 8))
    r = clahe.apply(r)
    g = clahe.apply(g)
    b = clahe.apply(b)

    # Merge the channels back together
    img_array = cv2.merge([r, g, b])

    # Convert back to PIL Image
    final_img = Image.fromarray(img_array)

    return final_img

# %%
# Define preprocessing pipeline
preprocess_pipeline = transforms.Compose([
    transforms.Lambda(lambda img: resize_with_aspect_ratio(img, 256)),  # Resize the image while maintaining the aspect ratio
    transforms.CenterCrop(256),  # Center crop the image
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),  # Random color jitter for generalization
    transforms.Lambda(lambda img: auto_exposure(img)),  # Apply auto exposure
    transforms.ToTensor(),  # Convert the image to PyTorch tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize the image
])

# %%
# Dictionary to store combined datasets for each class
datasets_by_class = {class_name: [] for class_name in labels.keys()}

# Accumulate datasets for each class
for source_dir in source_dirs:
    for class_name in labels.keys():
        class_path = os.path.join(source_dir, class_name)
        if not os.path.isdir(class_path):
            continue  # Skip if not a directory

        # Use ImageFolder with a structure that ImageFolder expects
        dataset = ImageFolder(root=source_dir, transform=preprocess_pipeline)

        # Filter dataset to include only images belonging to the current class
        class_indices = [i for i, (_, label) in enumerate(dataset.samples) if dataset.classes[label] == class_name]
        filtered_dataset = torch.utils.data.Subset(dataset, class_indices)
        
        # Append the filtered dataset to the list for this class
        datasets_by_class[class_name].append(filtered_dataset)

# %%
data_loaders_by_class = {}

for class_name, dataset_list in datasets_by_class.items():
    # Combine all filtered datasets for this class
    if len(dataset_list) > 1:
        combined_dataset = torch.utils.data.ConcatDataset(dataset_list)
    else:
        combined_dataset = dataset_list[0]  # If only one dataset, no need to concatenate

    # Create a single DataLoader for the combined dataset
    dataloader = DataLoader(combined_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
    data_loaders_by_class[class_name] = dataloader

    print(f'Loaded {len(combined_dataset)} images for class {class_name}.')
# Out:
# Loaded 320 images for class Paper.
# Loaded 432 images for class Rock.
# Loaded 312 images for class Scissor.

# %%
# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
else:
    # Delete directory if it already exists
    shutil.rmtree(output_dir)
    os.makedirs(output_dir)

print(f"Created/checked directory: {output_dir}")
# Out:
# Created/checked directory: ./preprocessed_images

# %%
print("Processing and saving images...")
for class_name, dataloader in data_loaders_by_class.items():
    print(f"Processing and saving images for class '{class_name}'...")
    
    # Create a subdirectory for the class
    class_dir = os.path.join(output_dir, class_name)
    os.makedirs(class_dir, exist_ok=True)

    # Iterate through the DataLoader batches
    for batch_idx, (images, labels) in enumerate(dataloader):
        print(f"Processing batch {batch_idx} of {label}...")
        for img_idx, image in enumerate(images):
            print(f"Processing image {img_idx+(batch_idx*img_idx)}...")

            # Generate a unique filename
            save_path = os.path.join(
                class_dir,
                f"{class_name}_{img_idx+(batch_idx*img_idx):03d}.jpg"
            )

            # Save the preprocessed image
            save_image(image, save_path)
            print(f"Saved: {save_path}")
            
        print(f"Batch {batch_idx} of {label} complete!")

print("Preprocessing complete!")
# Out:
# Processing and saving images...
# Processing and saving images for class 'Paper'...
# Processing batch 0...
# Processing image 0...
# Saved: ./preprocessed_images\Paper\Paper_000.jpg
# Processing image 1...
# Saved: ./preprocessed_images\Paper\Paper_001.jpg
# Processing image 2...
# Saved: ./preprocessed_images\Paper\Paper_002.jpg
# Processing image 3...
# Saved: ./preprocessed_images\Paper\Paper_003.jpg
# Processing image 4...
# Saved: ./preprocessed_images\Paper\Paper_004.jpg
# Processing image 5...
# Saved: ./preprocessed_images\Paper\Paper_005.jpg
# Processing image 6...
# Saved: ./preprocessed_images\Paper\Paper_006.jpg
# Processing image 7...
# Saved: ./preprocessed_images\Paper\Paper_007.jpg
# Processing image 8...
# Saved: ./preprocessed_images\Paper\Paper_008.jpg
# Processing image 9...
# Saved: ./preprocessed_images\Paper\Paper_009.jpg
# Processing image 10...
# Saved: ./preprocessed_images\Paper\Paper_010.jpg
# Processing image 11...
# Saved: ./preprocessed_images\Paper\Paper_011.jpg
# Processing image 12...
# Saved: ./preprocessed_images\Paper\Paper_012.jpg
# Processing image 13...
# Saved: ./preprocessed_images\Paper\Paper_013.jpg
# Processing image 14...
# Saved: ./preprocessed_images\Paper\Paper_014.jpg
# Processing image 15...
# Saved: ./preprocessed_images\Paper\Paper_015.jpg
# Processing image 16...
# Saved: ./preprocessed_images\Paper\Paper_016.jpg
# Processing image 17...
# Saved: ./preprocessed_images\Paper\Paper_017.jpg
# Processing image 18...
# Saved: ./preprocessed_images\Paper\Paper_018.jpg
# Processing image 19...
# Saved: ./preprocessed_images\Paper\Paper_019.jpg
# Processing image 20...
# Saved: ./preprocessed_images\Paper\Paper_020.jpg
# Processing image 21...
# Saved: ./preprocessed_images\Paper\Paper_021.jpg
# Processing image 22...
# Saved: ./preprocessed_images\Paper\Paper_022.jpg
# Processing image 23...
# Saved: ./preprocessed_images\Paper\Paper_023.jpg
# Processing image 24...
# Saved: ./preprocessed_images\Paper\Paper_024.jpg
# Processing image 25...
# Saved: ./preprocessed_images\Paper\Paper_025.jpg
# Processing image 26...
# Saved: ./preprocessed_images\Paper\Paper_026.jpg
# Processing image 27...
# Saved: ./preprocessed_images\Paper\Paper_027.jpg
# Processing image 28...
# Saved: ./preprocessed_images\Paper\Paper_028.jpg
# Processing image 29...
# Saved: ./preprocessed_images\Paper\Paper_029.jpg
# Processing image 30...
# Saved: ./preprocessed_images\Paper\Paper_030.jpg
# Processing image 31...
# Saved: ./preprocessed_images\Paper\Paper_031.jpg
# Processing image 32...
# Saved: ./preprocessed_images\Paper\Paper_032.jpg
# Processing image 33...
# Saved: ./preprocessed_images\Paper\Paper_033.jpg
# Processing image 34...
# Saved: ./preprocessed_images\Paper\Paper_034.jpg
# Processing image 35...
# Saved: ./preprocessed_images\Paper\Paper_035.jpg
# Processing image 36...
# Saved: ./preprocessed_images\Paper\Paper_036.jpg
# Processing image 37...
# Saved: ./preprocessed_images\Paper\Paper_037.jpg
# Processing image 38...
# Saved: ./preprocessed_images\Paper\Paper_038.jpg
# Processing image 39...
# Saved: ./preprocessed_images\Paper\Paper_039.jpg
# Processing image 40...
# Saved: ./preprocessed_images\Paper\Paper_040.jpg
# Processing image 41...
# Saved: ./preprocessed_images\Paper\Paper_041.jpg
# Processing image 42...
# Saved: ./preprocessed_images\Paper\Paper_042.jpg
# Processing image 43...
# Saved: ./preprocessed_images\Paper\Paper_043.jpg
# Processing image 44...
# Saved: ./preprocessed_images\Paper\Paper_044.jpg
# Processing image 45...
# Saved: ./preprocessed_images\Paper\Paper_045.jpg
# Processing image 46...
# Saved: ./preprocessed_images\Paper\Paper_046.jpg
# Processing image 47...
# Saved: ./preprocessed_images\Paper\Paper_047.jpg
# Processing image 48...
# Saved: ./preprocessed_images\Paper\Paper_048.jpg
# Processing image 49...
# Saved: ./preprocessed_images\Paper\Paper_049.jpg
# Processing image 50...
# Saved: ./preprocessed_images\Paper\Paper_050.jpg
# Processing image 51...
# Saved: ./preprocessed_images\Paper\Paper_051.jpg
# Processing image 52...
# Saved: ./preprocessed_images\Paper\Paper_052.jpg
# Processing image 53...
# Saved: ./preprocessed_images\Paper\Paper_053.jpg
# Processing image 54...
# Saved: ./preprocessed_images\Paper\Paper_054.jpg
# Processing image 55...
# Saved: ./preprocessed_images\Paper\Paper_055.jpg
# Processing image 56...
# Saved: ./preprocessed_images\Paper\Paper_056.jpg
# Processing image 57...
# Saved: ./preprocessed_images\Paper\Paper_057.jpg
# Processing image 58...
# Saved: ./preprocessed_images\Paper\Paper_058.jpg
# Processing image 59...
# Saved: ./preprocessed_images\Paper\Paper_059.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Paper\Paper_060.jpg
# Processing image 61...
# Saved: ./preprocessed_images\Paper\Paper_061.jpg
# Processing image 62...
# Saved: ./preprocessed_images\Paper\Paper_062.jpg
# Processing image 63...
# Saved: ./preprocessed_images\Paper\Paper_063.jpg
# Batch 0 complete!
# Processing batch 1...
# Processing image 0...
# Saved: ./preprocessed_images\Paper\Paper_000.jpg
# Processing image 2...
# Saved: ./preprocessed_images\Paper\Paper_002.jpg
# Processing image 4...
# Saved: ./preprocessed_images\Paper\Paper_004.jpg
# Processing image 6...
# Saved: ./preprocessed_images\Paper\Paper_006.jpg
# Processing image 8...
# Saved: ./preprocessed_images\Paper\Paper_008.jpg
# Processing image 10...
# Saved: ./preprocessed_images\Paper\Paper_010.jpg
# Processing image 12...
# Saved: ./preprocessed_images\Paper\Paper_012.jpg
# Processing image 14...
# Saved: ./preprocessed_images\Paper\Paper_014.jpg
# Processing image 16...
# Saved: ./preprocessed_images\Paper\Paper_016.jpg
# Processing image 18...
# Saved: ./preprocessed_images\Paper\Paper_018.jpg
# Processing image 20...
# Saved: ./preprocessed_images\Paper\Paper_020.jpg
# Processing image 22...
# Saved: ./preprocessed_images\Paper\Paper_022.jpg
# Processing image 24...
# Saved: ./preprocessed_images\Paper\Paper_024.jpg
# Processing image 26...
# Saved: ./preprocessed_images\Paper\Paper_026.jpg
# Processing image 28...
# Saved: ./preprocessed_images\Paper\Paper_028.jpg
# Processing image 30...
# Saved: ./preprocessed_images\Paper\Paper_030.jpg
# Processing image 32...
# Saved: ./preprocessed_images\Paper\Paper_032.jpg
# Processing image 34...
# Saved: ./preprocessed_images\Paper\Paper_034.jpg
# Processing image 36...
# Saved: ./preprocessed_images\Paper\Paper_036.jpg
# Processing image 38...
# Saved: ./preprocessed_images\Paper\Paper_038.jpg
# Processing image 40...
# Saved: ./preprocessed_images\Paper\Paper_040.jpg
# Processing image 42...
# Saved: ./preprocessed_images\Paper\Paper_042.jpg
# Processing image 44...
# Saved: ./preprocessed_images\Paper\Paper_044.jpg
# Processing image 46...
# Saved: ./preprocessed_images\Paper\Paper_046.jpg
# Processing image 48...
# Saved: ./preprocessed_images\Paper\Paper_048.jpg
# Processing image 50...
# Saved: ./preprocessed_images\Paper\Paper_050.jpg
# Processing image 52...
# Saved: ./preprocessed_images\Paper\Paper_052.jpg
# Processing image 54...
# Saved: ./preprocessed_images\Paper\Paper_054.jpg
# Processing image 56...
# Saved: ./preprocessed_images\Paper\Paper_056.jpg
# Processing image 58...
# Saved: ./preprocessed_images\Paper\Paper_058.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Paper\Paper_060.jpg
# Processing image 62...
# Saved: ./preprocessed_images\Paper\Paper_062.jpg
# Processing image 64...
# Saved: ./preprocessed_images\Paper\Paper_064.jpg
# Processing image 66...
# Saved: ./preprocessed_images\Paper\Paper_066.jpg
# Processing image 68...
# Saved: ./preprocessed_images\Paper\Paper_068.jpg
# Processing image 70...
# Saved: ./preprocessed_images\Paper\Paper_070.jpg
# Processing image 72...
# Saved: ./preprocessed_images\Paper\Paper_072.jpg
# Processing image 74...
# Saved: ./preprocessed_images\Paper\Paper_074.jpg
# Processing image 76...
# Saved: ./preprocessed_images\Paper\Paper_076.jpg
# Processing image 78...
# Saved: ./preprocessed_images\Paper\Paper_078.jpg
# Processing image 80...
# Saved: ./preprocessed_images\Paper\Paper_080.jpg
# Processing image 82...
# Saved: ./preprocessed_images\Paper\Paper_082.jpg
# Processing image 84...
# Saved: ./preprocessed_images\Paper\Paper_084.jpg
# Processing image 86...
# Saved: ./preprocessed_images\Paper\Paper_086.jpg
# Processing image 88...
# Saved: ./preprocessed_images\Paper\Paper_088.jpg
# Processing image 90...
# Saved: ./preprocessed_images\Paper\Paper_090.jpg
# Processing image 92...
# Saved: ./preprocessed_images\Paper\Paper_092.jpg
# Processing image 94...
# Saved: ./preprocessed_images\Paper\Paper_094.jpg
# Processing image 96...
# Saved: ./preprocessed_images\Paper\Paper_096.jpg
# Processing image 98...
# Saved: ./preprocessed_images\Paper\Paper_098.jpg
# Processing image 100...
# Saved: ./preprocessed_images\Paper\Paper_100.jpg
# Processing image 102...
# Saved: ./preprocessed_images\Paper\Paper_102.jpg
# Processing image 104...
# Saved: ./preprocessed_images\Paper\Paper_104.jpg
# Processing image 106...
# Saved: ./preprocessed_images\Paper\Paper_106.jpg
# Processing image 108...
# Saved: ./preprocessed_images\Paper\Paper_108.jpg
# Processing image 110...
# Saved: ./preprocessed_images\Paper\Paper_110.jpg
# Processing image 112...
# Saved: ./preprocessed_images\Paper\Paper_112.jpg
# Processing image 114...
# Saved: ./preprocessed_images\Paper\Paper_114.jpg
# Processing image 116...
# Saved: ./preprocessed_images\Paper\Paper_116.jpg
# Processing image 118...
# Saved: ./preprocessed_images\Paper\Paper_118.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Paper\Paper_120.jpg
# Processing image 122...
# Saved: ./preprocessed_images\Paper\Paper_122.jpg
# Processing image 124...
# Saved: ./preprocessed_images\Paper\Paper_124.jpg
# Processing image 126...
# Saved: ./preprocessed_images\Paper\Paper_126.jpg
# Batch 1 complete!
# Processing batch 2...
# Processing image 0...
# Saved: ./preprocessed_images\Paper\Paper_000.jpg
# Processing image 3...
# Saved: ./preprocessed_images\Paper\Paper_003.jpg
# Processing image 6...
# Saved: ./preprocessed_images\Paper\Paper_006.jpg
# Processing image 9...
# Saved: ./preprocessed_images\Paper\Paper_009.jpg
# Processing image 12...
# Saved: ./preprocessed_images\Paper\Paper_012.jpg
# Processing image 15...
# Saved: ./preprocessed_images\Paper\Paper_015.jpg
# Processing image 18...
# Saved: ./preprocessed_images\Paper\Paper_018.jpg
# Processing image 21...
# Saved: ./preprocessed_images\Paper\Paper_021.jpg
# Processing image 24...
# Saved: ./preprocessed_images\Paper\Paper_024.jpg
# Processing image 27...
# Saved: ./preprocessed_images\Paper\Paper_027.jpg
# Processing image 30...
# Saved: ./preprocessed_images\Paper\Paper_030.jpg
# Processing image 33...
# Saved: ./preprocessed_images\Paper\Paper_033.jpg
# Processing image 36...
# Saved: ./preprocessed_images\Paper\Paper_036.jpg
# Processing image 39...
# Saved: ./preprocessed_images\Paper\Paper_039.jpg
# Processing image 42...
# Saved: ./preprocessed_images\Paper\Paper_042.jpg
# Processing image 45...
# Saved: ./preprocessed_images\Paper\Paper_045.jpg
# Processing image 48...
# Saved: ./preprocessed_images\Paper\Paper_048.jpg
# Processing image 51...
# Saved: ./preprocessed_images\Paper\Paper_051.jpg
# Processing image 54...
# Saved: ./preprocessed_images\Paper\Paper_054.jpg
# Processing image 57...
# Saved: ./preprocessed_images\Paper\Paper_057.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Paper\Paper_060.jpg
# Processing image 63...
# Saved: ./preprocessed_images\Paper\Paper_063.jpg
# Processing image 66...
# Saved: ./preprocessed_images\Paper\Paper_066.jpg
# Processing image 69...
# Saved: ./preprocessed_images\Paper\Paper_069.jpg
# Processing image 72...
# Saved: ./preprocessed_images\Paper\Paper_072.jpg
# Processing image 75...
# Saved: ./preprocessed_images\Paper\Paper_075.jpg
# Processing image 78...
# Saved: ./preprocessed_images\Paper\Paper_078.jpg
# Processing image 81...
# Saved: ./preprocessed_images\Paper\Paper_081.jpg
# Processing image 84...
# Saved: ./preprocessed_images\Paper\Paper_084.jpg
# Processing image 87...
# Saved: ./preprocessed_images\Paper\Paper_087.jpg
# Processing image 90...
# Saved: ./preprocessed_images\Paper\Paper_090.jpg
# Processing image 93...
# Saved: ./preprocessed_images\Paper\Paper_093.jpg
# Processing image 96...
# Saved: ./preprocessed_images\Paper\Paper_096.jpg
# Processing image 99...
# Saved: ./preprocessed_images\Paper\Paper_099.jpg
# Processing image 102...
# Saved: ./preprocessed_images\Paper\Paper_102.jpg
# Processing image 105...
# Saved: ./preprocessed_images\Paper\Paper_105.jpg
# Processing image 108...
# Saved: ./preprocessed_images\Paper\Paper_108.jpg
# Processing image 111...
# Saved: ./preprocessed_images\Paper\Paper_111.jpg
# Processing image 114...
# Saved: ./preprocessed_images\Paper\Paper_114.jpg
# Processing image 117...
# Saved: ./preprocessed_images\Paper\Paper_117.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Paper\Paper_120.jpg
# Processing image 123...
# Saved: ./preprocessed_images\Paper\Paper_123.jpg
# Processing image 126...
# Saved: ./preprocessed_images\Paper\Paper_126.jpg
# Processing image 129...
# Saved: ./preprocessed_images\Paper\Paper_129.jpg
# Processing image 132...
# Saved: ./preprocessed_images\Paper\Paper_132.jpg
# Processing image 135...
# Saved: ./preprocessed_images\Paper\Paper_135.jpg
# Processing image 138...
# Saved: ./preprocessed_images\Paper\Paper_138.jpg
# Processing image 141...
# Saved: ./preprocessed_images\Paper\Paper_141.jpg
# Processing image 144...
# Saved: ./preprocessed_images\Paper\Paper_144.jpg
# Processing image 147...
# Saved: ./preprocessed_images\Paper\Paper_147.jpg
# Processing image 150...
# Saved: ./preprocessed_images\Paper\Paper_150.jpg
# Processing image 153...
# Saved: ./preprocessed_images\Paper\Paper_153.jpg
# Processing image 156...
# Saved: ./preprocessed_images\Paper\Paper_156.jpg
# Processing image 159...
# Saved: ./preprocessed_images\Paper\Paper_159.jpg
# Processing image 162...
# Saved: ./preprocessed_images\Paper\Paper_162.jpg
# Processing image 165...
# Saved: ./preprocessed_images\Paper\Paper_165.jpg
# Processing image 168...
# Saved: ./preprocessed_images\Paper\Paper_168.jpg
# Processing image 171...
# Saved: ./preprocessed_images\Paper\Paper_171.jpg
# Processing image 174...
# Saved: ./preprocessed_images\Paper\Paper_174.jpg
# Processing image 177...
# Saved: ./preprocessed_images\Paper\Paper_177.jpg
# Processing image 180...
# Saved: ./preprocessed_images\Paper\Paper_180.jpg
# Processing image 183...
# Saved: ./preprocessed_images\Paper\Paper_183.jpg
# Processing image 186...
# Saved: ./preprocessed_images\Paper\Paper_186.jpg
# Processing image 189...
# Saved: ./preprocessed_images\Paper\Paper_189.jpg
# Batch 2 complete!
# Processing batch 3...
# Processing image 0...
# Saved: ./preprocessed_images\Paper\Paper_000.jpg
# Processing image 4...
# Saved: ./preprocessed_images\Paper\Paper_004.jpg
# Processing image 8...
# Saved: ./preprocessed_images\Paper\Paper_008.jpg
# Processing image 12...
# Saved: ./preprocessed_images\Paper\Paper_012.jpg
# Processing image 16...
# Saved: ./preprocessed_images\Paper\Paper_016.jpg
# Processing image 20...
# Saved: ./preprocessed_images\Paper\Paper_020.jpg
# Processing image 24...
# Saved: ./preprocessed_images\Paper\Paper_024.jpg
# Processing image 28...
# Saved: ./preprocessed_images\Paper\Paper_028.jpg
# Processing image 32...
# Saved: ./preprocessed_images\Paper\Paper_032.jpg
# Processing image 36...
# Saved: ./preprocessed_images\Paper\Paper_036.jpg
# Processing image 40...
# Saved: ./preprocessed_images\Paper\Paper_040.jpg
# Processing image 44...
# Saved: ./preprocessed_images\Paper\Paper_044.jpg
# Processing image 48...
# Saved: ./preprocessed_images\Paper\Paper_048.jpg
# Processing image 52...
# Saved: ./preprocessed_images\Paper\Paper_052.jpg
# Processing image 56...
# Saved: ./preprocessed_images\Paper\Paper_056.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Paper\Paper_060.jpg
# Processing image 64...
# Saved: ./preprocessed_images\Paper\Paper_064.jpg
# Processing image 68...
# Saved: ./preprocessed_images\Paper\Paper_068.jpg
# Processing image 72...
# Saved: ./preprocessed_images\Paper\Paper_072.jpg
# Processing image 76...
# Saved: ./preprocessed_images\Paper\Paper_076.jpg
# Processing image 80...
# Saved: ./preprocessed_images\Paper\Paper_080.jpg
# Processing image 84...
# Saved: ./preprocessed_images\Paper\Paper_084.jpg
# Processing image 88...
# Saved: ./preprocessed_images\Paper\Paper_088.jpg
# Processing image 92...
# Saved: ./preprocessed_images\Paper\Paper_092.jpg
# Processing image 96...
# Saved: ./preprocessed_images\Paper\Paper_096.jpg
# Processing image 100...
# Saved: ./preprocessed_images\Paper\Paper_100.jpg
# Processing image 104...
# Saved: ./preprocessed_images\Paper\Paper_104.jpg
# Processing image 108...
# Saved: ./preprocessed_images\Paper\Paper_108.jpg
# Processing image 112...
# Saved: ./preprocessed_images\Paper\Paper_112.jpg
# Processing image 116...
# Saved: ./preprocessed_images\Paper\Paper_116.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Paper\Paper_120.jpg
# Processing image 124...
# Saved: ./preprocessed_images\Paper\Paper_124.jpg
# Processing image 128...
# Saved: ./preprocessed_images\Paper\Paper_128.jpg
# Processing image 132...
# Saved: ./preprocessed_images\Paper\Paper_132.jpg
# Processing image 136...
# Saved: ./preprocessed_images\Paper\Paper_136.jpg
# Processing image 140...
# Saved: ./preprocessed_images\Paper\Paper_140.jpg
# Processing image 144...
# Saved: ./preprocessed_images\Paper\Paper_144.jpg
# Processing image 148...
# Saved: ./preprocessed_images\Paper\Paper_148.jpg
# Processing image 152...
# Saved: ./preprocessed_images\Paper\Paper_152.jpg
# Processing image 156...
# Saved: ./preprocessed_images\Paper\Paper_156.jpg
# Processing image 160...
# Saved: ./preprocessed_images\Paper\Paper_160.jpg
# Processing image 164...
# Saved: ./preprocessed_images\Paper\Paper_164.jpg
# Processing image 168...
# Saved: ./preprocessed_images\Paper\Paper_168.jpg
# Processing image 172...
# Saved: ./preprocessed_images\Paper\Paper_172.jpg
# Processing image 176...
# Saved: ./preprocessed_images\Paper\Paper_176.jpg
# Processing image 180...
# Saved: ./preprocessed_images\Paper\Paper_180.jpg
# Processing image 184...
# Saved: ./preprocessed_images\Paper\Paper_184.jpg
# Processing image 188...
# Saved: ./preprocessed_images\Paper\Paper_188.jpg
# Processing image 192...
# Saved: ./preprocessed_images\Paper\Paper_192.jpg
# Processing image 196...
# Saved: ./preprocessed_images\Paper\Paper_196.jpg
# Processing image 200...
# Saved: ./preprocessed_images\Paper\Paper_200.jpg
# Processing image 204...
# Saved: ./preprocessed_images\Paper\Paper_204.jpg
# Processing image 208...
# Saved: ./preprocessed_images\Paper\Paper_208.jpg
# Processing image 212...
# Saved: ./preprocessed_images\Paper\Paper_212.jpg
# Processing image 216...
# Saved: ./preprocessed_images\Paper\Paper_216.jpg
# Processing image 220...
# Saved: ./preprocessed_images\Paper\Paper_220.jpg
# Processing image 224...
# Saved: ./preprocessed_images\Paper\Paper_224.jpg
# Processing image 228...
# Saved: ./preprocessed_images\Paper\Paper_228.jpg
# Processing image 232...
# Saved: ./preprocessed_images\Paper\Paper_232.jpg
# Processing image 236...
# Saved: ./preprocessed_images\Paper\Paper_236.jpg
# Processing image 240...
# Saved: ./preprocessed_images\Paper\Paper_240.jpg
# Processing image 244...
# Saved: ./preprocessed_images\Paper\Paper_244.jpg
# Processing image 248...
# Saved: ./preprocessed_images\Paper\Paper_248.jpg
# Processing image 252...
# Saved: ./preprocessed_images\Paper\Paper_252.jpg
# Batch 3 complete!
# Processing batch 4...
# Processing image 0...
# Saved: ./preprocessed_images\Paper\Paper_000.jpg
# Processing image 5...
# Saved: ./preprocessed_images\Paper\Paper_005.jpg
# Processing image 10...
# Saved: ./preprocessed_images\Paper\Paper_010.jpg
# Processing image 15...
# Saved: ./preprocessed_images\Paper\Paper_015.jpg
# Processing image 20...
# Saved: ./preprocessed_images\Paper\Paper_020.jpg
# Processing image 25...
# Saved: ./preprocessed_images\Paper\Paper_025.jpg
# Processing image 30...
# Saved: ./preprocessed_images\Paper\Paper_030.jpg
# Processing image 35...
# Saved: ./preprocessed_images\Paper\Paper_035.jpg
# Processing image 40...
# Saved: ./preprocessed_images\Paper\Paper_040.jpg
# Processing image 45...
# Saved: ./preprocessed_images\Paper\Paper_045.jpg
# Processing image 50...
# Saved: ./preprocessed_images\Paper\Paper_050.jpg
# Processing image 55...
# Saved: ./preprocessed_images\Paper\Paper_055.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Paper\Paper_060.jpg
# Processing image 65...
# Saved: ./preprocessed_images\Paper\Paper_065.jpg
# Processing image 70...
# Saved: ./preprocessed_images\Paper\Paper_070.jpg
# Processing image 75...
# Saved: ./preprocessed_images\Paper\Paper_075.jpg
# Processing image 80...
# Saved: ./preprocessed_images\Paper\Paper_080.jpg
# Processing image 85...
# Saved: ./preprocessed_images\Paper\Paper_085.jpg
# Processing image 90...
# Saved: ./preprocessed_images\Paper\Paper_090.jpg
# Processing image 95...
# Saved: ./preprocessed_images\Paper\Paper_095.jpg
# Processing image 100...
# Saved: ./preprocessed_images\Paper\Paper_100.jpg
# Processing image 105...
# Saved: ./preprocessed_images\Paper\Paper_105.jpg
# Processing image 110...
# Saved: ./preprocessed_images\Paper\Paper_110.jpg
# Processing image 115...
# Saved: ./preprocessed_images\Paper\Paper_115.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Paper\Paper_120.jpg
# Processing image 125...
# Saved: ./preprocessed_images\Paper\Paper_125.jpg
# Processing image 130...
# Saved: ./preprocessed_images\Paper\Paper_130.jpg
# Processing image 135...
# Saved: ./preprocessed_images\Paper\Paper_135.jpg
# Processing image 140...
# Saved: ./preprocessed_images\Paper\Paper_140.jpg
# Processing image 145...
# Saved: ./preprocessed_images\Paper\Paper_145.jpg
# Processing image 150...
# Saved: ./preprocessed_images\Paper\Paper_150.jpg
# Processing image 155...
# Saved: ./preprocessed_images\Paper\Paper_155.jpg
# Processing image 160...
# Saved: ./preprocessed_images\Paper\Paper_160.jpg
# Processing image 165...
# Saved: ./preprocessed_images\Paper\Paper_165.jpg
# Processing image 170...
# Saved: ./preprocessed_images\Paper\Paper_170.jpg
# Processing image 175...
# Saved: ./preprocessed_images\Paper\Paper_175.jpg
# Processing image 180...
# Saved: ./preprocessed_images\Paper\Paper_180.jpg
# Processing image 185...
# Saved: ./preprocessed_images\Paper\Paper_185.jpg
# Processing image 190...
# Saved: ./preprocessed_images\Paper\Paper_190.jpg
# Processing image 195...
# Saved: ./preprocessed_images\Paper\Paper_195.jpg
# Processing image 200...
# Saved: ./preprocessed_images\Paper\Paper_200.jpg
# Processing image 205...
# Saved: ./preprocessed_images\Paper\Paper_205.jpg
# Processing image 210...
# Saved: ./preprocessed_images\Paper\Paper_210.jpg
# Processing image 215...
# Saved: ./preprocessed_images\Paper\Paper_215.jpg
# Processing image 220...
# Saved: ./preprocessed_images\Paper\Paper_220.jpg
# Processing image 225...
# Saved: ./preprocessed_images\Paper\Paper_225.jpg
# Processing image 230...
# Saved: ./preprocessed_images\Paper\Paper_230.jpg
# Processing image 235...
# Saved: ./preprocessed_images\Paper\Paper_235.jpg
# Processing image 240...
# Saved: ./preprocessed_images\Paper\Paper_240.jpg
# Processing image 245...
# Saved: ./preprocessed_images\Paper\Paper_245.jpg
# Processing image 250...
# Saved: ./preprocessed_images\Paper\Paper_250.jpg
# Processing image 255...
# Saved: ./preprocessed_images\Paper\Paper_255.jpg
# Processing image 260...
# Saved: ./preprocessed_images\Paper\Paper_260.jpg
# Processing image 265...
# Saved: ./preprocessed_images\Paper\Paper_265.jpg
# Processing image 270...
# Saved: ./preprocessed_images\Paper\Paper_270.jpg
# Processing image 275...
# Saved: ./preprocessed_images\Paper\Paper_275.jpg
# Processing image 280...
# Saved: ./preprocessed_images\Paper\Paper_280.jpg
# Processing image 285...
# Saved: ./preprocessed_images\Paper\Paper_285.jpg
# Processing image 290...
# Saved: ./preprocessed_images\Paper\Paper_290.jpg
# Processing image 295...
# Saved: ./preprocessed_images\Paper\Paper_295.jpg
# Processing image 300...
# Saved: ./preprocessed_images\Paper\Paper_300.jpg
# Processing image 305...
# Saved: ./preprocessed_images\Paper\Paper_305.jpg
# Processing image 310...
# Saved: ./preprocessed_images\Paper\Paper_310.jpg
# Processing image 315...
# Saved: ./preprocessed_images\Paper\Paper_315.jpg
# Batch 4 complete!
# Processing and saving images for class 'Rock'...
# Processing batch 0...
# Processing image 0...
# Saved: ./preprocessed_images\Rock\Rock_000.jpg
# Processing image 1...
# Saved: ./preprocessed_images\Rock\Rock_001.jpg
# Processing image 2...
# Saved: ./preprocessed_images\Rock\Rock_002.jpg
# Processing image 3...
# Saved: ./preprocessed_images\Rock\Rock_003.jpg
# Processing image 4...
# Saved: ./preprocessed_images\Rock\Rock_004.jpg
# Processing image 5...
# Saved: ./preprocessed_images\Rock\Rock_005.jpg
# Processing image 6...
# Saved: ./preprocessed_images\Rock\Rock_006.jpg
# Processing image 7...
# Saved: ./preprocessed_images\Rock\Rock_007.jpg
# Processing image 8...
# Saved: ./preprocessed_images\Rock\Rock_008.jpg
# Processing image 9...
# Saved: ./preprocessed_images\Rock\Rock_009.jpg
# Processing image 10...
# Saved: ./preprocessed_images\Rock\Rock_010.jpg
# Processing image 11...
# Saved: ./preprocessed_images\Rock\Rock_011.jpg
# Processing image 12...
# Saved: ./preprocessed_images\Rock\Rock_012.jpg
# Processing image 13...
# Saved: ./preprocessed_images\Rock\Rock_013.jpg
# Processing image 14...
# Saved: ./preprocessed_images\Rock\Rock_014.jpg
# Processing image 15...
# Saved: ./preprocessed_images\Rock\Rock_015.jpg
# Processing image 16...
# Saved: ./preprocessed_images\Rock\Rock_016.jpg
# Processing image 17...
# Saved: ./preprocessed_images\Rock\Rock_017.jpg
# Processing image 18...
# Saved: ./preprocessed_images\Rock\Rock_018.jpg
# Processing image 19...
# Saved: ./preprocessed_images\Rock\Rock_019.jpg
# Processing image 20...
# Saved: ./preprocessed_images\Rock\Rock_020.jpg
# Processing image 21...
# Saved: ./preprocessed_images\Rock\Rock_021.jpg
# Processing image 22...
# Saved: ./preprocessed_images\Rock\Rock_022.jpg
# Processing image 23...
# Saved: ./preprocessed_images\Rock\Rock_023.jpg
# Processing image 24...
# Saved: ./preprocessed_images\Rock\Rock_024.jpg
# Processing image 25...
# Saved: ./preprocessed_images\Rock\Rock_025.jpg
# Processing image 26...
# Saved: ./preprocessed_images\Rock\Rock_026.jpg
# Processing image 27...
# Saved: ./preprocessed_images\Rock\Rock_027.jpg
# Processing image 28...
# Saved: ./preprocessed_images\Rock\Rock_028.jpg
# Processing image 29...
# Saved: ./preprocessed_images\Rock\Rock_029.jpg
# Processing image 30...
# Saved: ./preprocessed_images\Rock\Rock_030.jpg
# Processing image 31...
# Saved: ./preprocessed_images\Rock\Rock_031.jpg
# Processing image 32...
# Saved: ./preprocessed_images\Rock\Rock_032.jpg
# Processing image 33...
# Saved: ./preprocessed_images\Rock\Rock_033.jpg
# Processing image 34...
# Saved: ./preprocessed_images\Rock\Rock_034.jpg
# Processing image 35...
# Saved: ./preprocessed_images\Rock\Rock_035.jpg
# Processing image 36...
# Saved: ./preprocessed_images\Rock\Rock_036.jpg
# Processing image 37...
# Saved: ./preprocessed_images\Rock\Rock_037.jpg
# Processing image 38...
# Saved: ./preprocessed_images\Rock\Rock_038.jpg
# Processing image 39...
# Saved: ./preprocessed_images\Rock\Rock_039.jpg
# Processing image 40...
# Saved: ./preprocessed_images\Rock\Rock_040.jpg
# Processing image 41...
# Saved: ./preprocessed_images\Rock\Rock_041.jpg
# Processing image 42...
# Saved: ./preprocessed_images\Rock\Rock_042.jpg
# Processing image 43...
# Saved: ./preprocessed_images\Rock\Rock_043.jpg
# Processing image 44...
# Saved: ./preprocessed_images\Rock\Rock_044.jpg
# Processing image 45...
# Saved: ./preprocessed_images\Rock\Rock_045.jpg
# Processing image 46...
# Saved: ./preprocessed_images\Rock\Rock_046.jpg
# Processing image 47...
# Saved: ./preprocessed_images\Rock\Rock_047.jpg
# Processing image 48...
# Saved: ./preprocessed_images\Rock\Rock_048.jpg
# Processing image 49...
# Saved: ./preprocessed_images\Rock\Rock_049.jpg
# Processing image 50...
# Saved: ./preprocessed_images\Rock\Rock_050.jpg
# Processing image 51...
# Saved: ./preprocessed_images\Rock\Rock_051.jpg
# Processing image 52...
# Saved: ./preprocessed_images\Rock\Rock_052.jpg
# Processing image 53...
# Saved: ./preprocessed_images\Rock\Rock_053.jpg
# Processing image 54...
# Saved: ./preprocessed_images\Rock\Rock_054.jpg
# Processing image 55...
# Saved: ./preprocessed_images\Rock\Rock_055.jpg
# Processing image 56...
# Saved: ./preprocessed_images\Rock\Rock_056.jpg
# Processing image 57...
# Saved: ./preprocessed_images\Rock\Rock_057.jpg
# Processing image 58...
# Saved: ./preprocessed_images\Rock\Rock_058.jpg
# Processing image 59...
# Saved: ./preprocessed_images\Rock\Rock_059.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Rock\Rock_060.jpg
# Processing image 61...
# Saved: ./preprocessed_images\Rock\Rock_061.jpg
# Processing image 62...
# Saved: ./preprocessed_images\Rock\Rock_062.jpg
# Processing image 63...
# Saved: ./preprocessed_images\Rock\Rock_063.jpg
# Batch 0 complete!
# Processing batch 1...
# Processing image 0...
# Saved: ./preprocessed_images\Rock\Rock_000.jpg
# Processing image 2...
# Saved: ./preprocessed_images\Rock\Rock_002.jpg
# Processing image 4...
# Saved: ./preprocessed_images\Rock\Rock_004.jpg
# Processing image 6...
# Saved: ./preprocessed_images\Rock\Rock_006.jpg
# Processing image 8...
# Saved: ./preprocessed_images\Rock\Rock_008.jpg
# Processing image 10...
# Saved: ./preprocessed_images\Rock\Rock_010.jpg
# Processing image 12...
# Saved: ./preprocessed_images\Rock\Rock_012.jpg
# Processing image 14...
# Saved: ./preprocessed_images\Rock\Rock_014.jpg
# Processing image 16...
# Saved: ./preprocessed_images\Rock\Rock_016.jpg
# Processing image 18...
# Saved: ./preprocessed_images\Rock\Rock_018.jpg
# Processing image 20...
# Saved: ./preprocessed_images\Rock\Rock_020.jpg
# Processing image 22...
# Saved: ./preprocessed_images\Rock\Rock_022.jpg
# Processing image 24...
# Saved: ./preprocessed_images\Rock\Rock_024.jpg
# Processing image 26...
# Saved: ./preprocessed_images\Rock\Rock_026.jpg
# Processing image 28...
# Saved: ./preprocessed_images\Rock\Rock_028.jpg
# Processing image 30...
# Saved: ./preprocessed_images\Rock\Rock_030.jpg
# Processing image 32...
# Saved: ./preprocessed_images\Rock\Rock_032.jpg
# Processing image 34...
# Saved: ./preprocessed_images\Rock\Rock_034.jpg
# Processing image 36...
# Saved: ./preprocessed_images\Rock\Rock_036.jpg
# Processing image 38...
# Saved: ./preprocessed_images\Rock\Rock_038.jpg
# Processing image 40...
# Saved: ./preprocessed_images\Rock\Rock_040.jpg
# Processing image 42...
# Saved: ./preprocessed_images\Rock\Rock_042.jpg
# Processing image 44...
# Saved: ./preprocessed_images\Rock\Rock_044.jpg
# Processing image 46...
# Saved: ./preprocessed_images\Rock\Rock_046.jpg
# Processing image 48...
# Saved: ./preprocessed_images\Rock\Rock_048.jpg
# Processing image 50...
# Saved: ./preprocessed_images\Rock\Rock_050.jpg
# Processing image 52...
# Saved: ./preprocessed_images\Rock\Rock_052.jpg
# Processing image 54...
# Saved: ./preprocessed_images\Rock\Rock_054.jpg
# Processing image 56...
# Saved: ./preprocessed_images\Rock\Rock_056.jpg
# Processing image 58...
# Saved: ./preprocessed_images\Rock\Rock_058.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Rock\Rock_060.jpg
# Processing image 62...
# Saved: ./preprocessed_images\Rock\Rock_062.jpg
# Processing image 64...
# Saved: ./preprocessed_images\Rock\Rock_064.jpg
# Processing image 66...
# Saved: ./preprocessed_images\Rock\Rock_066.jpg
# Processing image 68...
# Saved: ./preprocessed_images\Rock\Rock_068.jpg
# Processing image 70...
# Saved: ./preprocessed_images\Rock\Rock_070.jpg
# Processing image 72...
# Saved: ./preprocessed_images\Rock\Rock_072.jpg
# Processing image 74...
# Saved: ./preprocessed_images\Rock\Rock_074.jpg
# Processing image 76...
# Saved: ./preprocessed_images\Rock\Rock_076.jpg
# Processing image 78...
# Saved: ./preprocessed_images\Rock\Rock_078.jpg
# Processing image 80...
# Saved: ./preprocessed_images\Rock\Rock_080.jpg
# Processing image 82...
# Saved: ./preprocessed_images\Rock\Rock_082.jpg
# Processing image 84...
# Saved: ./preprocessed_images\Rock\Rock_084.jpg
# Processing image 86...
# Saved: ./preprocessed_images\Rock\Rock_086.jpg
# Processing image 88...
# Saved: ./preprocessed_images\Rock\Rock_088.jpg
# Processing image 90...
# Saved: ./preprocessed_images\Rock\Rock_090.jpg
# Processing image 92...
# Saved: ./preprocessed_images\Rock\Rock_092.jpg
# Processing image 94...
# Saved: ./preprocessed_images\Rock\Rock_094.jpg
# Processing image 96...
# Saved: ./preprocessed_images\Rock\Rock_096.jpg
# Processing image 98...
# Saved: ./preprocessed_images\Rock\Rock_098.jpg
# Processing image 100...
# Saved: ./preprocessed_images\Rock\Rock_100.jpg
# Processing image 102...
# Saved: ./preprocessed_images\Rock\Rock_102.jpg
# Processing image 104...
# Saved: ./preprocessed_images\Rock\Rock_104.jpg
# Processing image 106...
# Saved: ./preprocessed_images\Rock\Rock_106.jpg
# Processing image 108...
# Saved: ./preprocessed_images\Rock\Rock_108.jpg
# Processing image 110...
# Saved: ./preprocessed_images\Rock\Rock_110.jpg
# Processing image 112...
# Saved: ./preprocessed_images\Rock\Rock_112.jpg
# Processing image 114...
# Saved: ./preprocessed_images\Rock\Rock_114.jpg
# Processing image 116...
# Saved: ./preprocessed_images\Rock\Rock_116.jpg
# Processing image 118...
# Saved: ./preprocessed_images\Rock\Rock_118.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Rock\Rock_120.jpg
# Processing image 122...
# Saved: ./preprocessed_images\Rock\Rock_122.jpg
# Processing image 124...
# Saved: ./preprocessed_images\Rock\Rock_124.jpg
# Processing image 126...
# Saved: ./preprocessed_images\Rock\Rock_126.jpg
# Batch 1 complete!
# Processing batch 2...
# Processing image 0...
# Saved: ./preprocessed_images\Rock\Rock_000.jpg
# Processing image 3...
# Saved: ./preprocessed_images\Rock\Rock_003.jpg
# Processing image 6...
# Saved: ./preprocessed_images\Rock\Rock_006.jpg
# Processing image 9...
# Saved: ./preprocessed_images\Rock\Rock_009.jpg
# Processing image 12...
# Saved: ./preprocessed_images\Rock\Rock_012.jpg
# Processing image 15...
# Saved: ./preprocessed_images\Rock\Rock_015.jpg
# Processing image 18...
# Saved: ./preprocessed_images\Rock\Rock_018.jpg
# Processing image 21...
# Saved: ./preprocessed_images\Rock\Rock_021.jpg
# Processing image 24...
# Saved: ./preprocessed_images\Rock\Rock_024.jpg
# Processing image 27...
# Saved: ./preprocessed_images\Rock\Rock_027.jpg
# Processing image 30...
# Saved: ./preprocessed_images\Rock\Rock_030.jpg
# Processing image 33...
# Saved: ./preprocessed_images\Rock\Rock_033.jpg
# Processing image 36...
# Saved: ./preprocessed_images\Rock\Rock_036.jpg
# Processing image 39...
# Saved: ./preprocessed_images\Rock\Rock_039.jpg
# Processing image 42...
# Saved: ./preprocessed_images\Rock\Rock_042.jpg
# Processing image 45...
# Saved: ./preprocessed_images\Rock\Rock_045.jpg
# Processing image 48...
# Saved: ./preprocessed_images\Rock\Rock_048.jpg
# Processing image 51...
# Saved: ./preprocessed_images\Rock\Rock_051.jpg
# Processing image 54...
# Saved: ./preprocessed_images\Rock\Rock_054.jpg
# Processing image 57...
# Saved: ./preprocessed_images\Rock\Rock_057.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Rock\Rock_060.jpg
# Processing image 63...
# Saved: ./preprocessed_images\Rock\Rock_063.jpg
# Processing image 66...
# Saved: ./preprocessed_images\Rock\Rock_066.jpg
# Processing image 69...
# Saved: ./preprocessed_images\Rock\Rock_069.jpg
# Processing image 72...
# Saved: ./preprocessed_images\Rock\Rock_072.jpg
# Processing image 75...
# Saved: ./preprocessed_images\Rock\Rock_075.jpg
# Processing image 78...
# Saved: ./preprocessed_images\Rock\Rock_078.jpg
# Processing image 81...
# Saved: ./preprocessed_images\Rock\Rock_081.jpg
# Processing image 84...
# Saved: ./preprocessed_images\Rock\Rock_084.jpg
# Processing image 87...
# Saved: ./preprocessed_images\Rock\Rock_087.jpg
# Processing image 90...
# Saved: ./preprocessed_images\Rock\Rock_090.jpg
# Processing image 93...
# Saved: ./preprocessed_images\Rock\Rock_093.jpg
# Processing image 96...
# Saved: ./preprocessed_images\Rock\Rock_096.jpg
# Processing image 99...
# Saved: ./preprocessed_images\Rock\Rock_099.jpg
# Processing image 102...
# Saved: ./preprocessed_images\Rock\Rock_102.jpg
# Processing image 105...
# Saved: ./preprocessed_images\Rock\Rock_105.jpg
# Processing image 108...
# Saved: ./preprocessed_images\Rock\Rock_108.jpg
# Processing image 111...
# Saved: ./preprocessed_images\Rock\Rock_111.jpg
# Processing image 114...
# Saved: ./preprocessed_images\Rock\Rock_114.jpg
# Processing image 117...
# Saved: ./preprocessed_images\Rock\Rock_117.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Rock\Rock_120.jpg
# Processing image 123...
# Saved: ./preprocessed_images\Rock\Rock_123.jpg
# Processing image 126...
# Saved: ./preprocessed_images\Rock\Rock_126.jpg
# Processing image 129...
# Saved: ./preprocessed_images\Rock\Rock_129.jpg
# Processing image 132...
# Saved: ./preprocessed_images\Rock\Rock_132.jpg
# Processing image 135...
# Saved: ./preprocessed_images\Rock\Rock_135.jpg
# Processing image 138...
# Saved: ./preprocessed_images\Rock\Rock_138.jpg
# Processing image 141...
# Saved: ./preprocessed_images\Rock\Rock_141.jpg
# Processing image 144...
# Saved: ./preprocessed_images\Rock\Rock_144.jpg
# Processing image 147...
# Saved: ./preprocessed_images\Rock\Rock_147.jpg
# Processing image 150...
# Saved: ./preprocessed_images\Rock\Rock_150.jpg
# Processing image 153...
# Saved: ./preprocessed_images\Rock\Rock_153.jpg
# Processing image 156...
# Saved: ./preprocessed_images\Rock\Rock_156.jpg
# Processing image 159...
# Saved: ./preprocessed_images\Rock\Rock_159.jpg
# Processing image 162...
# Saved: ./preprocessed_images\Rock\Rock_162.jpg
# Processing image 165...
# Saved: ./preprocessed_images\Rock\Rock_165.jpg
# Processing image 168...
# Saved: ./preprocessed_images\Rock\Rock_168.jpg
# Processing image 171...
# Saved: ./preprocessed_images\Rock\Rock_171.jpg
# Processing image 174...
# Saved: ./preprocessed_images\Rock\Rock_174.jpg
# Processing image 177...
# Saved: ./preprocessed_images\Rock\Rock_177.jpg
# Processing image 180...
# Saved: ./preprocessed_images\Rock\Rock_180.jpg
# Processing image 183...
# Saved: ./preprocessed_images\Rock\Rock_183.jpg
# Processing image 186...
# Saved: ./preprocessed_images\Rock\Rock_186.jpg
# Processing image 189...
# Saved: ./preprocessed_images\Rock\Rock_189.jpg
# Batch 2 complete!
# Processing batch 3...
# Processing image 0...
# Saved: ./preprocessed_images\Rock\Rock_000.jpg
# Processing image 4...
# Saved: ./preprocessed_images\Rock\Rock_004.jpg
# Processing image 8...
# Saved: ./preprocessed_images\Rock\Rock_008.jpg
# Processing image 12...
# Saved: ./preprocessed_images\Rock\Rock_012.jpg
# Processing image 16...
# Saved: ./preprocessed_images\Rock\Rock_016.jpg
# Processing image 20...
# Saved: ./preprocessed_images\Rock\Rock_020.jpg
# Processing image 24...
# Saved: ./preprocessed_images\Rock\Rock_024.jpg
# Processing image 28...
# Saved: ./preprocessed_images\Rock\Rock_028.jpg
# Processing image 32...
# Saved: ./preprocessed_images\Rock\Rock_032.jpg
# Processing image 36...
# Saved: ./preprocessed_images\Rock\Rock_036.jpg
# Processing image 40...
# Saved: ./preprocessed_images\Rock\Rock_040.jpg
# Processing image 44...
# Saved: ./preprocessed_images\Rock\Rock_044.jpg
# Processing image 48...
# Saved: ./preprocessed_images\Rock\Rock_048.jpg
# Processing image 52...
# Saved: ./preprocessed_images\Rock\Rock_052.jpg
# Processing image 56...
# Saved: ./preprocessed_images\Rock\Rock_056.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Rock\Rock_060.jpg
# Processing image 64...
# Saved: ./preprocessed_images\Rock\Rock_064.jpg
# Processing image 68...
# Saved: ./preprocessed_images\Rock\Rock_068.jpg
# Processing image 72...
# Saved: ./preprocessed_images\Rock\Rock_072.jpg
# Processing image 76...
# Saved: ./preprocessed_images\Rock\Rock_076.jpg
# Processing image 80...
# Saved: ./preprocessed_images\Rock\Rock_080.jpg
# Processing image 84...
# Saved: ./preprocessed_images\Rock\Rock_084.jpg
# Processing image 88...
# Saved: ./preprocessed_images\Rock\Rock_088.jpg
# Processing image 92...
# Saved: ./preprocessed_images\Rock\Rock_092.jpg
# Processing image 96...
# Saved: ./preprocessed_images\Rock\Rock_096.jpg
# Processing image 100...
# Saved: ./preprocessed_images\Rock\Rock_100.jpg
# Processing image 104...
# Saved: ./preprocessed_images\Rock\Rock_104.jpg
# Processing image 108...
# Saved: ./preprocessed_images\Rock\Rock_108.jpg
# Processing image 112...
# Saved: ./preprocessed_images\Rock\Rock_112.jpg
# Processing image 116...
# Saved: ./preprocessed_images\Rock\Rock_116.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Rock\Rock_120.jpg
# Processing image 124...
# Saved: ./preprocessed_images\Rock\Rock_124.jpg
# Processing image 128...
# Saved: ./preprocessed_images\Rock\Rock_128.jpg
# Processing image 132...
# Saved: ./preprocessed_images\Rock\Rock_132.jpg
# Processing image 136...
# Saved: ./preprocessed_images\Rock\Rock_136.jpg
# Processing image 140...
# Saved: ./preprocessed_images\Rock\Rock_140.jpg
# Processing image 144...
# Saved: ./preprocessed_images\Rock\Rock_144.jpg
# Processing image 148...
# Saved: ./preprocessed_images\Rock\Rock_148.jpg
# Processing image 152...
# Saved: ./preprocessed_images\Rock\Rock_152.jpg
# Processing image 156...
# Saved: ./preprocessed_images\Rock\Rock_156.jpg
# Processing image 160...
# Saved: ./preprocessed_images\Rock\Rock_160.jpg
# Processing image 164...
# Saved: ./preprocessed_images\Rock\Rock_164.jpg
# Processing image 168...
# Saved: ./preprocessed_images\Rock\Rock_168.jpg
# Processing image 172...
# Saved: ./preprocessed_images\Rock\Rock_172.jpg
# Processing image 176...
# Saved: ./preprocessed_images\Rock\Rock_176.jpg
# Processing image 180...
# Saved: ./preprocessed_images\Rock\Rock_180.jpg
# Processing image 184...
# Saved: ./preprocessed_images\Rock\Rock_184.jpg
# Processing image 188...
# Saved: ./preprocessed_images\Rock\Rock_188.jpg
# Processing image 192...
# Saved: ./preprocessed_images\Rock\Rock_192.jpg
# Processing image 196...
# Saved: ./preprocessed_images\Rock\Rock_196.jpg
# Processing image 200...
# Saved: ./preprocessed_images\Rock\Rock_200.jpg
# Processing image 204...
# Saved: ./preprocessed_images\Rock\Rock_204.jpg
# Processing image 208...
# Saved: ./preprocessed_images\Rock\Rock_208.jpg
# Processing image 212...
# Saved: ./preprocessed_images\Rock\Rock_212.jpg
# Processing image 216...
# Saved: ./preprocessed_images\Rock\Rock_216.jpg
# Processing image 220...
# Saved: ./preprocessed_images\Rock\Rock_220.jpg
# Processing image 224...
# Saved: ./preprocessed_images\Rock\Rock_224.jpg
# Processing image 228...
# Saved: ./preprocessed_images\Rock\Rock_228.jpg
# Processing image 232...
# Saved: ./preprocessed_images\Rock\Rock_232.jpg
# Processing image 236...
# Saved: ./preprocessed_images\Rock\Rock_236.jpg
# Processing image 240...
# Saved: ./preprocessed_images\Rock\Rock_240.jpg
# Processing image 244...
# Saved: ./preprocessed_images\Rock\Rock_244.jpg
# Processing image 248...
# Saved: ./preprocessed_images\Rock\Rock_248.jpg
# Processing image 252...
# Saved: ./preprocessed_images\Rock\Rock_252.jpg
# Batch 3 complete!
# Processing batch 4...
# Processing image 0...
# Saved: ./preprocessed_images\Rock\Rock_000.jpg
# Processing image 5...
# Saved: ./preprocessed_images\Rock\Rock_005.jpg
# Processing image 10...
# Saved: ./preprocessed_images\Rock\Rock_010.jpg
# Processing image 15...
# Saved: ./preprocessed_images\Rock\Rock_015.jpg
# Processing image 20...
# Saved: ./preprocessed_images\Rock\Rock_020.jpg
# Processing image 25...
# Saved: ./preprocessed_images\Rock\Rock_025.jpg
# Processing image 30...
# Saved: ./preprocessed_images\Rock\Rock_030.jpg
# Processing image 35...
# Saved: ./preprocessed_images\Rock\Rock_035.jpg
# Processing image 40...
# Saved: ./preprocessed_images\Rock\Rock_040.jpg
# Processing image 45...
# Saved: ./preprocessed_images\Rock\Rock_045.jpg
# Processing image 50...
# Saved: ./preprocessed_images\Rock\Rock_050.jpg
# Processing image 55...
# Saved: ./preprocessed_images\Rock\Rock_055.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Rock\Rock_060.jpg
# Processing image 65...
# Saved: ./preprocessed_images\Rock\Rock_065.jpg
# Processing image 70...
# Saved: ./preprocessed_images\Rock\Rock_070.jpg
# Processing image 75...
# Saved: ./preprocessed_images\Rock\Rock_075.jpg
# Processing image 80...
# Saved: ./preprocessed_images\Rock\Rock_080.jpg
# Processing image 85...
# Saved: ./preprocessed_images\Rock\Rock_085.jpg
# Processing image 90...
# Saved: ./preprocessed_images\Rock\Rock_090.jpg
# Processing image 95...
# Saved: ./preprocessed_images\Rock\Rock_095.jpg
# Processing image 100...
# Saved: ./preprocessed_images\Rock\Rock_100.jpg
# Processing image 105...
# Saved: ./preprocessed_images\Rock\Rock_105.jpg
# Processing image 110...
# Saved: ./preprocessed_images\Rock\Rock_110.jpg
# Processing image 115...
# Saved: ./preprocessed_images\Rock\Rock_115.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Rock\Rock_120.jpg
# Processing image 125...
# Saved: ./preprocessed_images\Rock\Rock_125.jpg
# Processing image 130...
# Saved: ./preprocessed_images\Rock\Rock_130.jpg
# Processing image 135...
# Saved: ./preprocessed_images\Rock\Rock_135.jpg
# Processing image 140...
# Saved: ./preprocessed_images\Rock\Rock_140.jpg
# Processing image 145...
# Saved: ./preprocessed_images\Rock\Rock_145.jpg
# Processing image 150...
# Saved: ./preprocessed_images\Rock\Rock_150.jpg
# Processing image 155...
# Saved: ./preprocessed_images\Rock\Rock_155.jpg
# Processing image 160...
# Saved: ./preprocessed_images\Rock\Rock_160.jpg
# Processing image 165...
# Saved: ./preprocessed_images\Rock\Rock_165.jpg
# Processing image 170...
# Saved: ./preprocessed_images\Rock\Rock_170.jpg
# Processing image 175...
# Saved: ./preprocessed_images\Rock\Rock_175.jpg
# Processing image 180...
# Saved: ./preprocessed_images\Rock\Rock_180.jpg
# Processing image 185...
# Saved: ./preprocessed_images\Rock\Rock_185.jpg
# Processing image 190...
# Saved: ./preprocessed_images\Rock\Rock_190.jpg
# Processing image 195...
# Saved: ./preprocessed_images\Rock\Rock_195.jpg
# Processing image 200...
# Saved: ./preprocessed_images\Rock\Rock_200.jpg
# Processing image 205...
# Saved: ./preprocessed_images\Rock\Rock_205.jpg
# Processing image 210...
# Saved: ./preprocessed_images\Rock\Rock_210.jpg
# Processing image 215...
# Saved: ./preprocessed_images\Rock\Rock_215.jpg
# Processing image 220...
# Saved: ./preprocessed_images\Rock\Rock_220.jpg
# Processing image 225...
# Saved: ./preprocessed_images\Rock\Rock_225.jpg
# Processing image 230...
# Saved: ./preprocessed_images\Rock\Rock_230.jpg
# Processing image 235...
# Saved: ./preprocessed_images\Rock\Rock_235.jpg
# Processing image 240...
# Saved: ./preprocessed_images\Rock\Rock_240.jpg
# Processing image 245...
# Saved: ./preprocessed_images\Rock\Rock_245.jpg
# Processing image 250...
# Saved: ./preprocessed_images\Rock\Rock_250.jpg
# Processing image 255...
# Saved: ./preprocessed_images\Rock\Rock_255.jpg
# Processing image 260...
# Saved: ./preprocessed_images\Rock\Rock_260.jpg
# Processing image 265...
# Saved: ./preprocessed_images\Rock\Rock_265.jpg
# Processing image 270...
# Saved: ./preprocessed_images\Rock\Rock_270.jpg
# Processing image 275...
# Saved: ./preprocessed_images\Rock\Rock_275.jpg
# Processing image 280...
# Saved: ./preprocessed_images\Rock\Rock_280.jpg
# Processing image 285...
# Saved: ./preprocessed_images\Rock\Rock_285.jpg
# Processing image 290...
# Saved: ./preprocessed_images\Rock\Rock_290.jpg
# Processing image 295...
# Saved: ./preprocessed_images\Rock\Rock_295.jpg
# Processing image 300...
# Saved: ./preprocessed_images\Rock\Rock_300.jpg
# Processing image 305...
# Saved: ./preprocessed_images\Rock\Rock_305.jpg
# Processing image 310...
# Saved: ./preprocessed_images\Rock\Rock_310.jpg
# Processing image 315...
# Saved: ./preprocessed_images\Rock\Rock_315.jpg
# Batch 4 complete!
# Processing batch 5...
# Processing image 0...
# Saved: ./preprocessed_images\Rock\Rock_000.jpg
# Processing image 6...
# Saved: ./preprocessed_images\Rock\Rock_006.jpg
# Processing image 12...
# Saved: ./preprocessed_images\Rock\Rock_012.jpg
# Processing image 18...
# Saved: ./preprocessed_images\Rock\Rock_018.jpg
# Processing image 24...
# Saved: ./preprocessed_images\Rock\Rock_024.jpg
# Processing image 30...
# Saved: ./preprocessed_images\Rock\Rock_030.jpg
# Processing image 36...
# Saved: ./preprocessed_images\Rock\Rock_036.jpg
# Processing image 42...
# Saved: ./preprocessed_images\Rock\Rock_042.jpg
# Processing image 48...
# Saved: ./preprocessed_images\Rock\Rock_048.jpg
# Processing image 54...
# Saved: ./preprocessed_images\Rock\Rock_054.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Rock\Rock_060.jpg
# Processing image 66...
# Saved: ./preprocessed_images\Rock\Rock_066.jpg
# Processing image 72...
# Saved: ./preprocessed_images\Rock\Rock_072.jpg
# Processing image 78...
# Saved: ./preprocessed_images\Rock\Rock_078.jpg
# Processing image 84...
# Saved: ./preprocessed_images\Rock\Rock_084.jpg
# Processing image 90...
# Saved: ./preprocessed_images\Rock\Rock_090.jpg
# Processing image 96...
# Saved: ./preprocessed_images\Rock\Rock_096.jpg
# Processing image 102...
# Saved: ./preprocessed_images\Rock\Rock_102.jpg
# Processing image 108...
# Saved: ./preprocessed_images\Rock\Rock_108.jpg
# Processing image 114...
# Saved: ./preprocessed_images\Rock\Rock_114.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Rock\Rock_120.jpg
# Processing image 126...
# Saved: ./preprocessed_images\Rock\Rock_126.jpg
# Processing image 132...
# Saved: ./preprocessed_images\Rock\Rock_132.jpg
# Processing image 138...
# Saved: ./preprocessed_images\Rock\Rock_138.jpg
# Processing image 144...
# Saved: ./preprocessed_images\Rock\Rock_144.jpg
# Processing image 150...
# ...
# Saved: ./preprocessed_images\Scissor\Scissor_082.jpg
# Processing image 84...
# Saved: ./preprocessed_images\Scissor\Scissor_084.jpg
# Processing image 86...
# Saved: ./preprocessed_images\Scissor\Scissor_086.jpg
# Processing image 88...
# Saved: ./preprocessed_images\Scissor\Scissor_088.jpg
# Processing image 90...
# Saved: ./preprocessed_images\Scissor\Scissor_090.jpg
# Processing image 92...
# Saved: ./preprocessed_images\Scissor\Scissor_092.jpg
# Processing image 94...
# Saved: ./preprocessed_images\Scissor\Scissor_094.jpg
# Processing image 96...
# Saved: ./preprocessed_images\Scissor\Scissor_096.jpg
# Processing image 98...
# Saved: ./preprocessed_images\Scissor\Scissor_098.jpg
# Processing image 100...
# Saved: ./preprocessed_images\Scissor\Scissor_100.jpg
# Processing image 102...
# Saved: ./preprocessed_images\Scissor\Scissor_102.jpg
# Processing image 104...
# Saved: ./preprocessed_images\Scissor\Scissor_104.jpg
# Processing image 106...
# Saved: ./preprocessed_images\Scissor\Scissor_106.jpg
# Processing image 108...
# Saved: ./preprocessed_images\Scissor\Scissor_108.jpg
# Processing image 110...
# Saved: ./preprocessed_images\Scissor\Scissor_110.jpg
# Processing image 112...
# Saved: ./preprocessed_images\Scissor\Scissor_112.jpg
# Processing image 114...
# Saved: ./preprocessed_images\Scissor\Scissor_114.jpg
# Processing image 116...
# Saved: ./preprocessed_images\Scissor\Scissor_116.jpg
# Processing image 118...
# Saved: ./preprocessed_images\Scissor\Scissor_118.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Scissor\Scissor_120.jpg
# Processing image 122...
# Saved: ./preprocessed_images\Scissor\Scissor_122.jpg
# Processing image 124...
# Saved: ./preprocessed_images\Scissor\Scissor_124.jpg
# Processing image 126...
# Saved: ./preprocessed_images\Scissor\Scissor_126.jpg
# Batch 1 complete!
# Processing batch 2...
# Processing image 0...
# Saved: ./preprocessed_images\Scissor\Scissor_000.jpg
# Processing image 3...
# Saved: ./preprocessed_images\Scissor\Scissor_003.jpg
# Processing image 6...
# Saved: ./preprocessed_images\Scissor\Scissor_006.jpg
# Processing image 9...
# Saved: ./preprocessed_images\Scissor\Scissor_009.jpg
# Processing image 12...
# Saved: ./preprocessed_images\Scissor\Scissor_012.jpg
# Processing image 15...
# Saved: ./preprocessed_images\Scissor\Scissor_015.jpg
# Processing image 18...
# Saved: ./preprocessed_images\Scissor\Scissor_018.jpg
# Processing image 21...
# Saved: ./preprocessed_images\Scissor\Scissor_021.jpg
# Processing image 24...
# Saved: ./preprocessed_images\Scissor\Scissor_024.jpg
# Processing image 27...
# Saved: ./preprocessed_images\Scissor\Scissor_027.jpg
# Processing image 30...
# Saved: ./preprocessed_images\Scissor\Scissor_030.jpg
# Processing image 33...
# Saved: ./preprocessed_images\Scissor\Scissor_033.jpg
# Processing image 36...
# Saved: ./preprocessed_images\Scissor\Scissor_036.jpg
# Processing image 39...
# Saved: ./preprocessed_images\Scissor\Scissor_039.jpg
# Processing image 42...
# Saved: ./preprocessed_images\Scissor\Scissor_042.jpg
# Processing image 45...
# Saved: ./preprocessed_images\Scissor\Scissor_045.jpg
# Processing image 48...
# Saved: ./preprocessed_images\Scissor\Scissor_048.jpg
# Processing image 51...
# Saved: ./preprocessed_images\Scissor\Scissor_051.jpg
# Processing image 54...
# Saved: ./preprocessed_images\Scissor\Scissor_054.jpg
# Processing image 57...
# Saved: ./preprocessed_images\Scissor\Scissor_057.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Scissor\Scissor_060.jpg
# Processing image 63...
# Saved: ./preprocessed_images\Scissor\Scissor_063.jpg
# Processing image 66...
# Saved: ./preprocessed_images\Scissor\Scissor_066.jpg
# Processing image 69...
# Saved: ./preprocessed_images\Scissor\Scissor_069.jpg
# Processing image 72...
# Saved: ./preprocessed_images\Scissor\Scissor_072.jpg
# Processing image 75...
# Saved: ./preprocessed_images\Scissor\Scissor_075.jpg
# Processing image 78...
# Saved: ./preprocessed_images\Scissor\Scissor_078.jpg
# Processing image 81...
# Saved: ./preprocessed_images\Scissor\Scissor_081.jpg
# Processing image 84...
# Saved: ./preprocessed_images\Scissor\Scissor_084.jpg
# Processing image 87...
# Saved: ./preprocessed_images\Scissor\Scissor_087.jpg
# Processing image 90...
# Saved: ./preprocessed_images\Scissor\Scissor_090.jpg
# Processing image 93...
# Saved: ./preprocessed_images\Scissor\Scissor_093.jpg
# Processing image 96...
# Saved: ./preprocessed_images\Scissor\Scissor_096.jpg
# Processing image 99...
# Saved: ./preprocessed_images\Scissor\Scissor_099.jpg
# Processing image 102...
# Saved: ./preprocessed_images\Scissor\Scissor_102.jpg
# Processing image 105...
# Saved: ./preprocessed_images\Scissor\Scissor_105.jpg
# Processing image 108...
# Saved: ./preprocessed_images\Scissor\Scissor_108.jpg
# Processing image 111...
# Saved: ./preprocessed_images\Scissor\Scissor_111.jpg
# Processing image 114...
# Saved: ./preprocessed_images\Scissor\Scissor_114.jpg
# Processing image 117...
# Saved: ./preprocessed_images\Scissor\Scissor_117.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Scissor\Scissor_120.jpg
# Processing image 123...
# Saved: ./preprocessed_images\Scissor\Scissor_123.jpg
# Processing image 126...
# Saved: ./preprocessed_images\Scissor\Scissor_126.jpg
# Processing image 129...
# Saved: ./preprocessed_images\Scissor\Scissor_129.jpg
# Processing image 132...
# Saved: ./preprocessed_images\Scissor\Scissor_132.jpg
# Processing image 135...
# Saved: ./preprocessed_images\Scissor\Scissor_135.jpg
# Processing image 138...
# Saved: ./preprocessed_images\Scissor\Scissor_138.jpg
# Processing image 141...
# Saved: ./preprocessed_images\Scissor\Scissor_141.jpg
# Processing image 144...
# Saved: ./preprocessed_images\Scissor\Scissor_144.jpg
# Processing image 147...
# Saved: ./preprocessed_images\Scissor\Scissor_147.jpg
# Processing image 150...
# Saved: ./preprocessed_images\Scissor\Scissor_150.jpg
# Processing image 153...
# Saved: ./preprocessed_images\Scissor\Scissor_153.jpg
# Processing image 156...
# Saved: ./preprocessed_images\Scissor\Scissor_156.jpg
# Processing image 159...
# Saved: ./preprocessed_images\Scissor\Scissor_159.jpg
# Processing image 162...
# Saved: ./preprocessed_images\Scissor\Scissor_162.jpg
# Processing image 165...
# Saved: ./preprocessed_images\Scissor\Scissor_165.jpg
# Processing image 168...
# Saved: ./preprocessed_images\Scissor\Scissor_168.jpg
# Processing image 171...
# Saved: ./preprocessed_images\Scissor\Scissor_171.jpg
# Processing image 174...
# Saved: ./preprocessed_images\Scissor\Scissor_174.jpg
# Processing image 177...
# Saved: ./preprocessed_images\Scissor\Scissor_177.jpg
# Processing image 180...
# Saved: ./preprocessed_images\Scissor\Scissor_180.jpg
# Processing image 183...
# Saved: ./preprocessed_images\Scissor\Scissor_183.jpg
# Processing image 186...
# Saved: ./preprocessed_images\Scissor\Scissor_186.jpg
# Processing image 189...
# Saved: ./preprocessed_images\Scissor\Scissor_189.jpg
# Batch 2 complete!
# Processing batch 3...
# Processing image 0...
# Saved: ./preprocessed_images\Scissor\Scissor_000.jpg
# Processing image 4...
# Saved: ./preprocessed_images\Scissor\Scissor_004.jpg
# Processing image 8...
# Saved: ./preprocessed_images\Scissor\Scissor_008.jpg
# Processing image 12...
# Saved: ./preprocessed_images\Scissor\Scissor_012.jpg
# Processing image 16...
# Saved: ./preprocessed_images\Scissor\Scissor_016.jpg
# Processing image 20...
# Saved: ./preprocessed_images\Scissor\Scissor_020.jpg
# Processing image 24...
# Saved: ./preprocessed_images\Scissor\Scissor_024.jpg
# Processing image 28...
# Saved: ./preprocessed_images\Scissor\Scissor_028.jpg
# Processing image 32...
# Saved: ./preprocessed_images\Scissor\Scissor_032.jpg
# Processing image 36...
# Saved: ./preprocessed_images\Scissor\Scissor_036.jpg
# Processing image 40...
# Saved: ./preprocessed_images\Scissor\Scissor_040.jpg
# Processing image 44...
# Saved: ./preprocessed_images\Scissor\Scissor_044.jpg
# Processing image 48...
# Saved: ./preprocessed_images\Scissor\Scissor_048.jpg
# Processing image 52...
# Saved: ./preprocessed_images\Scissor\Scissor_052.jpg
# Processing image 56...
# Saved: ./preprocessed_images\Scissor\Scissor_056.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Scissor\Scissor_060.jpg
# Processing image 64...
# Saved: ./preprocessed_images\Scissor\Scissor_064.jpg
# Processing image 68...
# Saved: ./preprocessed_images\Scissor\Scissor_068.jpg
# Processing image 72...
# Saved: ./preprocessed_images\Scissor\Scissor_072.jpg
# Processing image 76...
# Saved: ./preprocessed_images\Scissor\Scissor_076.jpg
# Processing image 80...
# Saved: ./preprocessed_images\Scissor\Scissor_080.jpg
# Processing image 84...
# Saved: ./preprocessed_images\Scissor\Scissor_084.jpg
# Processing image 88...
# Saved: ./preprocessed_images\Scissor\Scissor_088.jpg
# Processing image 92...
# Saved: ./preprocessed_images\Scissor\Scissor_092.jpg
# Processing image 96...
# Saved: ./preprocessed_images\Scissor\Scissor_096.jpg
# Processing image 100...
# Saved: ./preprocessed_images\Scissor\Scissor_100.jpg
# Processing image 104...
# Saved: ./preprocessed_images\Scissor\Scissor_104.jpg
# Processing image 108...
# Saved: ./preprocessed_images\Scissor\Scissor_108.jpg
# Processing image 112...
# Saved: ./preprocessed_images\Scissor\Scissor_112.jpg
# Processing image 116...
# Saved: ./preprocessed_images\Scissor\Scissor_116.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Scissor\Scissor_120.jpg
# Processing image 124...
# Saved: ./preprocessed_images\Scissor\Scissor_124.jpg
# Processing image 128...
# Saved: ./preprocessed_images\Scissor\Scissor_128.jpg
# Processing image 132...
# Saved: ./preprocessed_images\Scissor\Scissor_132.jpg
# Processing image 136...
# Saved: ./preprocessed_images\Scissor\Scissor_136.jpg
# Processing image 140...
# Saved: ./preprocessed_images\Scissor\Scissor_140.jpg
# Processing image 144...
# Saved: ./preprocessed_images\Scissor\Scissor_144.jpg
# Processing image 148...
# Saved: ./preprocessed_images\Scissor\Scissor_148.jpg
# Processing image 152...
# Saved: ./preprocessed_images\Scissor\Scissor_152.jpg
# Processing image 156...
# Saved: ./preprocessed_images\Scissor\Scissor_156.jpg
# Processing image 160...
# Saved: ./preprocessed_images\Scissor\Scissor_160.jpg
# Processing image 164...
# Saved: ./preprocessed_images\Scissor\Scissor_164.jpg
# Processing image 168...
# Saved: ./preprocessed_images\Scissor\Scissor_168.jpg
# Processing image 172...
# Saved: ./preprocessed_images\Scissor\Scissor_172.jpg
# Processing image 176...
# Saved: ./preprocessed_images\Scissor\Scissor_176.jpg
# Processing image 180...
# Saved: ./preprocessed_images\Scissor\Scissor_180.jpg
# Processing image 184...
# Saved: ./preprocessed_images\Scissor\Scissor_184.jpg
# Processing image 188...
# Saved: ./preprocessed_images\Scissor\Scissor_188.jpg
# Processing image 192...
# Saved: ./preprocessed_images\Scissor\Scissor_192.jpg
# Processing image 196...
# Saved: ./preprocessed_images\Scissor\Scissor_196.jpg
# Processing image 200...
# Saved: ./preprocessed_images\Scissor\Scissor_200.jpg
# Processing image 204...
# Saved: ./preprocessed_images\Scissor\Scissor_204.jpg
# Processing image 208...
# Saved: ./preprocessed_images\Scissor\Scissor_208.jpg
# Processing image 212...
# Saved: ./preprocessed_images\Scissor\Scissor_212.jpg
# Processing image 216...
# Saved: ./preprocessed_images\Scissor\Scissor_216.jpg
# Processing image 220...
# Saved: ./preprocessed_images\Scissor\Scissor_220.jpg
# Processing image 224...
# Saved: ./preprocessed_images\Scissor\Scissor_224.jpg
# Processing image 228...
# Saved: ./preprocessed_images\Scissor\Scissor_228.jpg
# Processing image 232...
# Saved: ./preprocessed_images\Scissor\Scissor_232.jpg
# Processing image 236...
# Saved: ./preprocessed_images\Scissor\Scissor_236.jpg
# Processing image 240...
# Saved: ./preprocessed_images\Scissor\Scissor_240.jpg
# Processing image 244...
# Saved: ./preprocessed_images\Scissor\Scissor_244.jpg
# Processing image 248...
# Saved: ./preprocessed_images\Scissor\Scissor_248.jpg
# Processing image 252...
# Saved: ./preprocessed_images\Scissor\Scissor_252.jpg
# Batch 3 complete!
# Processing batch 4...
# Processing image 0...
# Saved: ./preprocessed_images\Scissor\Scissor_000.jpg
# Processing image 5...
# Saved: ./preprocessed_images\Scissor\Scissor_005.jpg
# Processing image 10...
# Saved: ./preprocessed_images\Scissor\Scissor_010.jpg
# Processing image 15...
# Saved: ./preprocessed_images\Scissor\Scissor_015.jpg
# Processing image 20...
# Saved: ./preprocessed_images\Scissor\Scissor_020.jpg
# Processing image 25...
# Saved: ./preprocessed_images\Scissor\Scissor_025.jpg
# Processing image 30...
# Saved: ./preprocessed_images\Scissor\Scissor_030.jpg
# Processing image 35...
# Saved: ./preprocessed_images\Scissor\Scissor_035.jpg
# Processing image 40...
# Saved: ./preprocessed_images\Scissor\Scissor_040.jpg
# Processing image 45...
# Saved: ./preprocessed_images\Scissor\Scissor_045.jpg
# Processing image 50...
# Saved: ./preprocessed_images\Scissor\Scissor_050.jpg
# Processing image 55...
# Saved: ./preprocessed_images\Scissor\Scissor_055.jpg
# Processing image 60...
# Saved: ./preprocessed_images\Scissor\Scissor_060.jpg
# Processing image 65...
# Saved: ./preprocessed_images\Scissor\Scissor_065.jpg
# Processing image 70...
# Saved: ./preprocessed_images\Scissor\Scissor_070.jpg
# Processing image 75...
# Saved: ./preprocessed_images\Scissor\Scissor_075.jpg
# Processing image 80...
# Saved: ./preprocessed_images\Scissor\Scissor_080.jpg
# Processing image 85...
# Saved: ./preprocessed_images\Scissor\Scissor_085.jpg
# Processing image 90...
# Saved: ./preprocessed_images\Scissor\Scissor_090.jpg
# Processing image 95...
# Saved: ./preprocessed_images\Scissor\Scissor_095.jpg
# Processing image 100...
# Saved: ./preprocessed_images\Scissor\Scissor_100.jpg
# Processing image 105...
# Saved: ./preprocessed_images\Scissor\Scissor_105.jpg
# Processing image 110...
# Saved: ./preprocessed_images\Scissor\Scissor_110.jpg
# Processing image 115...
# Saved: ./preprocessed_images\Scissor\Scissor_115.jpg
# Processing image 120...
# Saved: ./preprocessed_images\Scissor\Scissor_120.jpg
# Processing image 125...
# Saved: ./preprocessed_images\Scissor\Scissor_125.jpg
# Processing image 130...
# Saved: ./preprocessed_images\Scissor\Scissor_130.jpg
# Processing image 135...
# Saved: ./preprocessed_images\Scissor\Scissor_135.jpg
# Processing image 140...
# Saved: ./preprocessed_images\Scissor\Scissor_140.jpg
# Processing image 145...
# Saved: ./preprocessed_images\Scissor\Scissor_145.jpg
# Processing image 150...
# Saved: ./preprocessed_images\Scissor\Scissor_150.jpg
# Processing image 155...
# Saved: ./preprocessed_images\Scissor\Scissor_155.jpg
# Processing image 160...
# Saved: ./preprocessed_images\Scissor\Scissor_160.jpg
# Processing image 165...
# Saved: ./preprocessed_images\Scissor\Scissor_165.jpg
# Processing image 170...
# Saved: ./preprocessed_images\Scissor\Scissor_170.jpg
# Processing image 175...
# Saved: ./preprocessed_images\Scissor\Scissor_175.jpg
# Processing image 180...
# Saved: ./preprocessed_images\Scissor\Scissor_180.jpg
# Processing image 185...
# Saved: ./preprocessed_images\Scissor\Scissor_185.jpg
# Processing image 190...
# Saved: ./preprocessed_images\Scissor\Scissor_190.jpg
# Processing image 195...
# Saved: ./preprocessed_images\Scissor\Scissor_195.jpg
# Processing image 200...
# Saved: ./preprocessed_images\Scissor\Scissor_200.jpg
# Processing image 205...
# Saved: ./preprocessed_images\Scissor\Scissor_205.jpg
# Processing image 210...
# Saved: ./preprocessed_images\Scissor\Scissor_210.jpg
# Processing image 215...
# Saved: ./preprocessed_images\Scissor\Scissor_215.jpg
# Processing image 220...
# Saved: ./preprocessed_images\Scissor\Scissor_220.jpg
# Processing image 225...
# Saved: ./preprocessed_images\Scissor\Scissor_225.jpg
# Processing image 230...
# Saved: ./preprocessed_images\Scissor\Scissor_230.jpg
# Processing image 235...
# Saved: ./preprocessed_images\Scissor\Scissor_235.jpg
# Processing image 240...
# Saved: ./preprocessed_images\Scissor\Scissor_240.jpg
# Processing image 245...
# Saved: ./preprocessed_images\Scissor\Scissor_245.jpg
# Processing image 250...
# Saved: ./preprocessed_images\Scissor\Scissor_250.jpg
# Processing image 255...
# Saved: ./preprocessed_images\Scissor\Scissor_255.jpg
# Processing image 260...
# Saved: ./preprocessed_images\Scissor\Scissor_260.jpg
# Processing image 265...
# Saved: ./preprocessed_images\Scissor\Scissor_265.jpg
# Processing image 270...
# Saved: ./preprocessed_images\Scissor\Scissor_270.jpg
# Processing image 275...
# Saved: ./preprocessed_images\Scissor\Scissor_275.jpg
# Batch 4 complete!
# Preprocessing complete!
